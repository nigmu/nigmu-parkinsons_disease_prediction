# %%
# SILENCE REMOVAL FROM ITALIAN DATA


import os
import time
from pydub import AudioSegment
from pydub.silence import split_on_silence

# input_root= "/media/nigmu/android/Dataset(Linux)/Italian Original Dataset"
# output_root = "/media/nigmu/android/Dataset(Linux)/Italian Silenced Dataset"

input_root= os.path.join("Dataset", "Italian Original Dataset")
output_root = os.path.join("Dataset", "Italian Silenced Dataset")

def process_audio(file_path, output_path):
    start = time.time()
    sound = AudioSegment.from_file(file_path, format="wav")
    
    # Silence removal parameters
    audio_chunks = split_on_silence(
        sound, 
        min_silence_len=100,
        silence_thresh=-40,
        keep_silence=50
    )
    
    # Merge all chunks back together
    combined = AudioSegment.empty()
    for chunk in audio_chunks:
        combined += chunk
    
    # Create necessary output directories
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    # Export the processed file
    combined.export(output_path, format="wav")
    
    duration = time.time() - start
    print(f"Processed in {duration:.2f}s: {os.path.basename(file_path)}")

total_start = time.time()

# Process both HC and PD directories
for group in ["HC", "PD"]:
    input_folder = os.path.join(input_root, group)
    output_folder = os.path.join(output_root, group)

    # Walk through all subdirectories recursively
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".wav"):
                # Get relative path to maintain folder structure
                relative_path = os.path.relpath(root, input_folder)
                in_path = os.path.join(root, file)
                out_path = os.path.join(output_folder, relative_path, file)
                
                process_audio(in_path, out_path)

total_duration = time.time() - total_start
print(f"\n✅ All files processed in {total_duration:.2f} seconds")
# Out:
# /home/nigmu/pytorch_env/lib/python3.12/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# Processed in 0.30s: B1APNOTROC49M230320170926.wav
# Processed in 0.10s: VE1APNOTROC49M230320170929.wav
# Processed in 0.03s: VU2APNOTROC49M230320170932.wav
# Processed in 0.05s: VA1APNOTROC49M230320170928.wav
# Processed in 0.03s: D2APNOTROC49M230320170928.wav
# Processed in 0.28s: B2APNOTROC49M230320170927.wav
# Processed in 0.09s: VU1APNOTROC49M230320170932.wav
# Processed in 0.03s: D1APNOTROC49M230320170928.wav
# Processed in 0.12s: FB1APNOTROC49M230320170934.wav
# Processed in 0.03s: VA2APNOTROC49M230320170929.wav
# Processed in 0.18s: PR1APNOTROC49M230320170933.wav
# Processed in 0.10s: VI1APNOTROC49M230320170930.wav
# Processed in 0.03s: VI2APNOTROC49M230320170930.wav
# Processed in 0.03s: VE2APNOTROC49M230320170930.wav
# Processed in 0.07s: VO1APNOTROC49M230320170931.wav
# Processed in 0.03s: VO2APNOTROC49M230320170931.wav
# Processed in 0.19s: FB1GGIAORVG47F300320171218.wav
# Processed in 0.04s: VE1GGIAORVG47F300320171213.wav
# Processed in 0.03s: D2GGIAORVG47F300320171212.wav
# Processed in 0.05s: VI1GGIAORVG47F300320171214.wav
# Processed in 0.03s: VO2GGIAORVG47F300320171215.wav
# Processed in 0.06s: VU1GGIAORVG47F300320171215.wav
# Processed in 0.51s: B2GGIAORVG47F300320171210.wav
# Processed in 0.06s: VA1GGIAORVG47F300320171212.wav
# Processed in 0.71s: B1GGIAORVG47F300320171207.wav
# Processed in 0.03s: VI2GGIAORVG47F300320171214.wav
# Processed in 0.03s: VA2GGIAORVG47F300320171213.wav
# Processed in 0.05s: VO1GGIAORVG47F300320171214.wav
# Processed in 0.03s: VU2GGIAORVG47F300320171215.wav
# Processed in 0.32s: PR1GGIAORVG47F300320171217.wav
# Processed in 0.03s: VE2GGIAORVG47F300320171214.wav
# Processed in 0.03s: D1GGIAORVG47F300320171212.wav
# Processed in 0.03s: VI1TMEIRAEC54F230320171154.wav
# Processed in 0.31s: B2TMEIRAEC54F230320171152.wav
# Processed in 0.27s: PR1TMEIRAEC54F230320171157.wav
# Processed in 0.03s: VU2TMEIRAEC54F230320171155.wav
# Processed in 0.03s: VU1TMEIRAEC54F230320171155.wav
# Processed in 0.03s: VO2TMEIRAEC54F230320171155.wav
# Processed in 0.04s: VA1TMEIRAEC54F230320171153.wav
# Processed in 0.17s: FB1TMEIRAEC54F230320171158.wav
# Processed in 0.38s: B1TMEIRAEC54F230320171150.wav
# Processed in 0.03s: VI2TMEIRAEC54F230320171154.wav
# Processed in 0.03s: D2TMEIRAEC54F230320171152.wav
# Processed in 0.03s: VO1TMEIRAEC54F230320171155.wav
# Processed in 0.03s: VE2TMEIRAEC54F230320171154.wav
# Processed in 0.03s: VE1TMEIRAEC54F230320171154.wav
# Processed in 0.03s: D1TMEIRAEC54F230320171152.wav
# Processed in 0.03s: VA2TMEIRAEC54F230320171153.wav
# Processed in 0.03s: VU2APGANRET55F170320171112.wav
# Processed in 0.05s: VO1APGANRET55F170320171111.wav
# Processed in 0.38s: B2APGANRET55F170320171105.wav
# Processed in 0.05s: VI1APGANRET55F170320171109.wav
# Processed in 0.03s: VO2APGANRET55F170320171111.wav
# Processed in 0.06s: VA1APGANRET55F170320171107.wav
# Processed in 0.19s: FB1APGANRET55F170320171115.wav
# Processed in 0.04s: D2APGANRET55F170320171107.wav
# Processed in 0.03s: VA2APGANRET55F170320171108.wav
# Processed in 0.03s: VI2APGANRET55F170320171110.wav
# Processed in 0.05s: VU1APGANRET55F170320171112.wav
# Processed in 0.32s: PR1APGANRET55F170320171114.wav
# Processed in 0.51s: B1APGANRET55F170320171104.wav
# Processed in 0.05s: VE1APGANRET55F170320171109.wav
# Processed in 0.03s: D1APGANRET55F170320171106.wav
# Processed in 0.03s: VE2APGANRET55F170320171109.wav
# Processed in 0.26s: B2APNITNOT56F230320170849.wav
# Processed in 0.03s: D2APNITNOT56F230320170850.wav
# Processed in 0.03s: VI2APNITNOT56F230320170853.wav
# Processed in 0.05s: VO1APNITNOT56F230320170854.wav
# Processed in 0.03s: VE2APNITNOT56F230320170852.wav
# Processed in 0.06s: VA1APNITNOT56F230320170850.wav
# Processed in 0.03s: VU2APNITNOT56F230320170855.wav
# Processed in 0.04s: VE1APNITNOT56F230320170851.wav
# Processed in 0.05s: VU1APNITNOT56F230320170855.wav
# Processed in 0.03s: D1APNITNOT56F230320170849.wav
# Processed in 0.22s: PR1APNITNOT56F230320170856.wav
# Processed in 0.06s: VI1APNITNOT56F230320170852.wav
# Processed in 0.03s: VO2APNITNOT56F230320170854.wav
# Processed in 0.13s: FB1APNITNOT56F230320170857.wav
# Processed in 0.33s: B1APNITNOT56F230320170847.wav
# Processed in 0.03s: VA2APNITNOT56F230320170851.wav
# Processed in 0.03s: VI2GLIIUSSC57M210320171054.wav
# Processed in 0.30s: B1GLIIUSSC57M210320171050.wav
# Processed in 0.03s: VE2GLIIUSSC57M210320171053.wav
# Processed in 0.08s: VU1GLIIUSSC57M210320171055.wav
# Processed in 0.03s: VA2GLIIUSSC57M210320171053.wav
# Processed in 0.07s: VO1GLIIUSSC57M210320171055.wav
# Processed in 0.04s: D1GLIIUSSC57M210320171052.wav
# Processed in 0.03s: D2GLIIUSSC57M210320171052.wav
# Processed in 0.19s: PR1GLIIUSSC57M210320171057.wav
# Processed in 0.07s: VI1GLIIUSSC57M210320171054.wav
# Processed in 0.03s: VU2GLIIUSSC57M210320171056.wav
# Processed in 0.09s: VA1GLIIUSSC57M210320171052.wav
# Processed in 0.03s: VO2GLIIUSSC57M210320171055.wav
# Processed in 0.11s: VE1GLIIUSSC57M210320171053.wav
# Processed in 0.27s: B2GLIIUSSC57M210320171051.wav
# Processed in 0.12s: FB1GLIIUSSC57M210320171058.wav
# Processed in 0.20s: B1LBULCAAS94M100120171053.wav
# Processed in 0.19s: B2LBULCAAS94M100120171053.wav
# Processed in 0.19s: PR1LBULCAAS94M100120171053.wav
# Processed in 0.03s: VI2GCIALSDA52F170320171129.wav
# Processed in 0.03s: VA2GCIALSDA52F170320171127.wav
# Processed in 0.28s: B2GCIALSDA52F170320171125.wav
# Processed in 0.21s: PR1GCIALSDA52F170320171132.wav
# Processed in 0.05s: VU1GCIALSDA52F170320171130.wav
# Processed in 0.03s: D2GCIALSDA52F170320171126.wav
# Processed in 0.05s: VO1GCIALSDA52F170320171129.wav
# Processed in 0.05s: VA1GCIALSDA52F170320171127.wav
# Processed in 0.03s: VE2GCIALSDA52F170320171128.wav
# Processed in 0.08s: VI1GCIALSDA52F170320171128.wav
# Processed in 0.03s: VO2GCIALSDA52F170320171130.wav
# Processed in 0.35s: B1GCIALSDA52F170320171124.wav
# Processed in 0.03s: D1GCIALSDA52F170320171126.wav
# Processed in 0.13s: FB1GCIALSDA52F170320171133.wav
# Processed in 0.03s: VU2GCIALSDA52F170320171130.wav
# Processed in 0.08s: VE1GCIALSDA52F170320171127.wav
# Processed in 0.03s: VO2VDIET AS47M210320170945.wav
# Processed in 0.07s: VO1VDIET AS47M210320170945.wav
# Processed in 0.03s: VU2VDIET AS47M210320170945.wav
# Processed in 0.04s: D2VDIET AS47M210320170946.wav
# Processed in 0.05s: VE1VDIET AS47M210320170943.wav
# Processed in 0.04s: VA1VDIET AS47M210320170942.wav
# Processed in 0.04s: VE2VDIET AS47M210320170944.wav
# Processed in 0.03s: D1VDIET AS47M210320170946.wav
# Processed in 0.05s: VI1VDIET AS47M210320170944.wav
# Processed in 0.04s: VI2VDIET AS47M210320170944.wav
# Processed in 0.04s: VA2VDIET AS47M210320170943.wav
# Processed in 0.33s: PR1VDIETAS47M210320170948.wav
# Processed in 0.07s: VI1BCRAISGS48F210320171007.wav
# Processed in 0.20s: B1LBULCAAS94M100120171036.wav
# Processed in 0.19s: B2LBULCAAS94M100120171036.wav
# Processed in 0.22s: PR1LBULCAAS94M100120171036.wav
# Processed in 0.23s: B2LBULCAAS94M100120171064.wav
# Processed in 0.26s: B1LBULCAAS94M100120171064.wav
# Processed in 0.22s: PR1LBULCAAS94M100120171064.wav
# Processed in 0.07s: VI1MPAERRIR56F300320171147.wav
# Processed in 0.03s: VE2MPAERRIR56F300320171147.wav
# Processed in 0.03s: VA2MPAERRIR56F300320171146.wav
# Processed in 0.03s: VU2MPAERRIR56F300320171149.wav
# Processed in 0.27s: B2MPAERRIR56F300320171145.wav
# Processed in 0.09s: VU1MPAERRIR56F300320171149.wav
# Processed in 0.03s: D1MPAERRIR56F300320171145.wav
# Processed in 0.28s: PR1MPAERRIR56F300320171150.wav
# Processed in 0.28s: B1MPAERRIR56F300320171143.wav
# Processed in 0.06s: VO1MPAERRIR56F300320171148.wav
# Processed in 0.06s: VE1MPAERRIR56F300320171147.wav
# Processed in 0.03s: VI2MPAERRIR56F300320171148.wav
# Processed in 0.04s: VA1MPAERRIR56F300320171146.wav
# Processed in 0.03s: VO2MPAERRIR56F300320171148.wav
# Processed in 0.14s: FB1MPAERRIR56F300320171151.wav
# Processed in 0.03s: D2MPAERRIR56F300320171145.wav
# Processed in 0.22s: B2LBULCAAS94M100120171023.wav
# Processed in 0.26s: PR1LBULCAAS94M100120171023.wav
# Processed in 0.22s: B1LBULCAAS94M100120171023.wav
# Processed in 0.04s: VO1AGNIGNEE54F230320171022.wav
# Processed in 0.22s: PR1AGNIGNEE54F230320171024.wav
# Processed in 0.04s: VE1AGNIGNEE54F230320171021.wav
# Processed in 0.03s: D2AGNIGNEE54F230320171020.wav
# Processed in 0.03s: VU2AGNIGNEE54F230320171023.wav
# Processed in 0.03s: VO2AGNIGNEE54F230320171022.wav
# Processed in 0.35s: B2AGNIGNEE54F230320171019.wav
# Processed in 0.06s: VU1AGNIGNEE54F230320171022.wav
# Processed in 0.03s: D1AGNIGNEE54F230320171019.wav
# Processed in 0.04s: VI1AGNIGNEE54F230320171021.wav
# Processed in 0.03s: VE2AGNIGNEE54F230320171021.wav
# Processed in 0.17s: FB1AGNIGNEE54F230320171025.wav
# Processed in 0.09s: VA1AGNIGNEE54F230320171020.wav
# Processed in 0.03s: VI2AGNIGNEE54F230320171022.wav
# Processed in 0.03s: VA2AGNIGNEE54F230320171021.wav
# Processed in 0.35s: B1AGNIGNEE54F230320171018.wav
# Processed in 0.24s: B1LBULCAAS94M100120171021.wav
# Processed in 0.23s: B2LBULCAAS94M100120171021.wav
# Processed in 0.29s: PR1LBULCAAS94M100120171021.wav
# Processed in 0.10s: VU1LSUUIMGM48F230320171057.wav
# Processed in 0.03s: VE2LSUUIMGM48F230320171054.wav
# Processed in 0.17s: PR1LSUUIMGM48F230320171058.wav
# Processed in 0.03s: VU2LSUUIMGM48F230320171057.wav
# Processed in 0.27s: B2LSUUIMGM48F230320171050.wav
# Processed in 0.03s: D2LSUUIMGM48F230320171051.wav
# Processed in 0.09s: VI1LSUUIMGM48F230320171055.wav
# Processed in 0.12s: VO1LSUUIMGM48F230320171056.wav
# Processed in 0.14s: FB1LSUUIMGM48F230320171059.wav
# Processed in 0.03s: VI2LSUUIMGM48F230320171055.wav
# Processed in 0.03s: VA2LSUUIMGM48F230320171053.wav
# Processed in 0.03s: VO2LSUUIMGM48F230320171056.wav
# Processed in 0.32s: B1LSUUIMGM48F230320171049.wav
# Processed in 0.10s: VA1LSUUIMGM48F230320171053.wav
# Processed in 0.10s: VE1LSUUIMGM48F230320171054.wav
# Processed in 0.03s: D1LSUUIMGM48F230320171051.wav
# Processed in 0.03s: VI2ACNUTCOC40M230320171126.wav
# Processed in 0.05s: VE1ACNUTCOC40M230320171126.wav
# Processed in 0.03s: VA2ACNUTCOC40M230320171125.wav
# Processed in 0.31s: B1ACNUTCOC40M230320171121.wav
# Processed in 0.30s: B2ACNUTCOC40M230320171123.wav
# Processed in 0.03s: VA1ACNUTCOC40M230320171125.wav
# Processed in 0.05s: VU1ACNUTCOC40M230320171128.wav
# Processed in 0.30s: PR1ACNUTCOC40M230320171129.wav
# Processed in 0.03s: D2ACNUTCOC40M230320171124.wav
# Processed in 0.03s: VU2ACNUTCOC40M230320171128.wav
# Processed in 0.05s: VI1ACNUTCOC40M230320171126.wav
# Processed in 0.03s: VE2ACNUTCOC40M230320171126.wav
# Processed in 0.05s: VO1ACNUTCOC40M230320171127.wav
# Processed in 0.03s: VO2ACNUTCOC40M230320171127.wav
# Processed in 0.14s: FB1ACNUTCOC40M230320171130.wav
# Processed in 0.03s: D1ACNUTCOC40M230320171124.wav
# Processed in 0.19s: B2LBULCAAS94M100120171015.wav
# Processed in 0.22s: PR1LBULCAAS94M100120171015..wav
# Processed in 0.18s: B1LBULCAAS94M100120171015.wav
# Processed in 0.15s: FB1LPUUITGI41M230320171116.wav
# Processed in 0.03s: VU2LPUUITGI41M230320171114.wav
# Processed in 0.03s: VA2LPUUITGI41M230320171111.wav
# Processed in 0.03s: VI2LPUUITGI41M230320171113.wav
# Processed in 0.04s: D1LPUUITGI41M230320171110.wav
# Processed in 0.04s: D2LPUUITGI41M230320171111.wav
# Processed in 0.06s: VA1LPUUITGI41M230320171111.wav
# Processed in 0.25s: PR1LPUUITGI41M230320171115.wav
# Processed in 0.29s: B1LPUUITGI41M230320171109.wav
# Processed in 0.27s: B2LPUUITGI41M230320171110.wav
# Processed in 0.06s: VO1LPUUITGI41M230320171113.wav
# Processed in 0.03s: VE2LPUUITGI41M230320171112.wav
# Processed in 0.06s: VE1LPUUITGI41M230320171112.wav
# Processed in 0.06s: VU1LPUUITGI41M230320171114.wav
# Processed in 0.03s: VO2LPUUITGI41M230320171113.wav
# Processed in 0.06s: VI1LPUUITGI41M230320171113.wav
# Processed in 0.22s: B1LBULCAAS94M100120171017.wav
# Processed in 0.24s: PR1LBULCAAS94M100120171017.wav
# Processed in 0.22s: B2LBULCAAS94M100120171017.wav
# Processed in 0.19s: B1LBULCAAS94M100120171056.wav
# Processed in 0.20s: B2LBULCAAS94M100120171056.wav
# Processed in 0.20s: PR1LBULCAAS94M100120171056.wav
# Processed in 0.21s: B1TDULCAAS94M100120171065.wav
# Processed in 0.17s: PR1LBULCAAS94M100120171065.wav
# Processed in 0.20s: B2LBULCAAS94M100120171065.wav
# Processed in 0.06s: VE1GBIAORVI48M230320171236.wav
# Processed in 0.08s: VU1GBIAORVI48M230320171239.wav
# Processed in 0.03s: VO2GBIAORVI48M230320171239.wav
# Processed in 0.14s: FB1GBIAORVI48M230320171241.wav
# Processed in 0.03s: VA2GBIAORVI48M230320171236.wav
# Processed in 0.03s: VE2GBIAORVI48M230320171237.wav
# Processed in 0.32s: B1GBIAORVI48M230320171233.wav
# Processed in 0.03s: D2GBIAORVI48M230320171235.wav
# Processed in 0.08s: VA1GBIAORVI48M230320171236.wav
# Processed in 0.03s: D1GBIAORVI48M230320171235.wav
# Processed in 0.07s: VO1GBIAORVI48M230320171238.wav
# Processed in 0.03s: VI2GBIAORVI48M230320171238.wav
# Processed in 0.03s: VU2GBIAORVI48M230320171239.wav
# Processed in 0.08s: VI1GBIAORVI48M230320171237.wav
# Processed in 0.19s: PR1GBIAORVI48M230320171240.wav
# Processed in 0.32s: B2GBIAORVI48M230320171234.wav
# Processed in 0.03s: VO2LFEIOONR57F210320171128.wav
# Processed in 0.08s: VO1LFEIOONR57F210320171128.wav
# Processed in 0.05s: VE1LFEIOONR57F210320171126.wav
# Processed in 0.08s: VU1LFEIOONR57F210320171128.wav
# Processed in 0.06s: VI1LFEIOONR57F210320171127.wav
# Processed in 0.03s: D2LFEIOONR57F210320171125.wav
# Processed in 0.03s: VA2LFEIOONR57F210320171126.wav
# Processed in 0.22s: PR1LFEIOONR57F210320171130.wav
# Processed in 0.04s: VA1LFEIOONR57F210320171126.wav
# Processed in 0.03s: D1LFEIOONR57F210320171125.wav
# Processed in 0.27s: B2LFEIOONR57F210320171124.wav
# Processed in 0.03s: VI2LFEIOONR57F210320171127.wav
# Processed in 0.03s: VU2LFEIOONR57F210320171128.wav
# Processed in 0.29s: B1LFEIOONR57F210320171120.wav
# Processed in 0.03s: VE2LFEIOONR57F210320171127.wav
# Processed in 0.17s: FB1LFEIOONR57F210320171131.wav
# Processed in 0.13s: VU1VLIATFOO55M300320171248.wav
# Processed in 0.45s: B1VLIATFOO55M300320171237.wav
# Processed in 0.12s: VI1VLIATFOO55M300320171247.wav
# Processed in 0.15s: FB1VLIATFOO55M300320171243.wav
# Processed in 0.03s: VU2VLIATFOO55M300320171249.wav
# Processed in 0.03s: D1VLIATFOO55M300320171244.wav
# Processed in 0.03s: VA2VLIATFOO55M300320171245.wav
# Processed in 0.03s: D2VLIATFOO55M300320171244.wav
# Processed in 0.14s: VE1VLIATFOO55M300320171246.wav
# Processed in 0.24s: PR1VLIATFOO55M300320171241.wav
# Processed in 0.11s: VA1VLIATFOO55M300320171245.wav
# Processed in 0.03s: VE2VLIATFOO55M300320171246.wav
# Processed in 0.03s: VO2VLIATFOO55M300320171248.wav
# Processed in 0.13s: VO1VLIATFOO55M300320171247.wav
# Processed in 0.35s: B2VLIATFOO55M300320171238.wav
# Processed in 0.03s: VI2VLIATFOO55M300320171247.wav
# Processed in 0.10s: VE1MGIACTHT49M210320170856.wav
# Processed in 0.11s: VA1MGIACTHT49M210320170855.wav
# Processed in 0.03s: VE2MGIACTHT49M210320170857.wav
# Processed in 0.04s: VA2MGIACTHT49M210320170856.wav
# Processed in 0.07s: VO1MGIACTHT49M210320170859.wav
# Processed in 0.28s: B2MGIACTHT49M210320170850.wav
# Processed in 0.13s: FB1MGIACTHT49M210320170904.wav
# Processed in 0.03s: D1MGIACTHT49M210320170854.wav
# Processed in 0.22s: PR1MGIACTHT49M210320170903.wav
# Processed in 0.07s: VU1MGIACTHT49M210320170900.wav
# Processed in 0.08s: VI1MGIACTHT49M210320170859.wav
# Processed in 0.03s: D2MGIACTHT49M210320170855.wav
# Processed in 0.03s: VU2MGIACTHT49M210320170901.wav
# Processed in 0.03s: VI2MGIACTHT49M210320170859.wav
# Processed in 0.30s: B1MGIACTHT49M210320170848.wav
# Processed in 0.03s: VO2MGIACTHT49M210320170900.wav
# Processed in 0.24s: B1LBULCAAS94M100120171063.wav
# Processed in 0.22s: B2LBULCAAS94M100120171063.wav
# Processed in 0.19s: PR1LBULCAAS94M100120171063.wav
# Processed in 0.19s: PR1LBULCAAS94M100120171043.wav
# Processed in 0.21s: B2LBULCAAS94M100120171043.wav
# Processed in 0.21s: B1LBULCAAS94M100120171043.wav
# Processed in 0.26s: B2LBULCAAS94M100120171066.wav
# Processed in 0.22s: PR1LBULCAAS94M100120171066.wav
# Processed in 0.23s: B1LBULCAAS94M100120171066.wav
# Processed in 0.24s: PR11LBULCAAS94M100120171057.wav
# Processed in 0.22s: B2LBULCAAS94M100120171057.wav
# Processed in 0.22s: B1LBULCAAS94M100120171057.wav
# Processed in 0.26s: B2VAILTFOO49M230320171030.wav
# Processed in 0.05s: VA1VAILTFOO49M230320171031.wav
# Processed in 0.03s: D2VAILTFOO49M230320171031.wav
# Processed in 0.05s: VI1VAILTFOO49M230320171032.wav
# Processed in 0.03s: D1VAILTFOO49M230320171030.wav
# Processed in 0.03s: VU2VAILTFOO49M230320171034.wav
# Processed in 0.21s: PR1VAILTFOO49M230320171035.wav
# Processed in 0.03s: VA2VAILTFOO49M230320171031.wav
# Processed in 0.13s: FB1VAILTFOO49M230320171036.wav
# Processed in 0.03s: VO2VAILTFOO49M230320171033.wav
# Processed in 0.05s: VU1VAILTFOO49M230320171033.wav
# Processed in 0.04s: VE1VAILTFOO49M230320171032.wav
# Processed in 0.03s: VI2VAILTFOO49M230320171033.wav
# Processed in 0.04s: VO1VAILTFOO49M230320171033.wav
# Processed in 0.30s: B1VAILTFOO49M230320171029.wav
# Processed in 0.03s: VE2VAILTFOO49M230320171032.wav
# Processed in 0.20s: B2LBULCAAS94M100120171016.wav
# Processed in 0.19s: B1AMULCAAS94M100120171016.wav
# Processed in 0.05s: VA1NCIICAOC52M100220171239.wav
# Processed in 0.06s: VO1NCIICAOC52M100220171242.wav
# Processed in 0.03s: VA2NCIICAOC52M100220171240.wav
# Processed in 0.05s: VI1NCIICAOC52M100220171241.wav
# Processed in 0.03s: VI2NCIICAOC52M100220171241.wav
# Processed in 0.03s: VE2NCIICAOC52M100220171240.wav
# Processed in 0.03s: VE1NCIICAOC52M100220171240.wav
# Processed in 1.22s: B1NCIICAOC52M100220171237.wav
# Processed in 0.03s: D2NCIICAOC52M100220171239.wav
# Processed in 1.15s: PR1NCIICAOC52M100220171249.wav
# Processed in 0.05s: VU1NCIICAOC52M100220171243.wav
# Processed in 0.03s: D1NCIICAOC52M100220171238.wav
# Processed in 0.03s: VU2NCIICAOC52M100220171244.wav
# Processed in 0.05s: D2sncihcio44M1606161719.wav
# Processed in 0.03s: D2NSICCHOI44M240120171845.wav
# Processed in 0.53s: B2sncihcio44M1606161718.wav
# Processed in 0.34s: B2NSICCHOI44M240120171843.wav
# Processed in 0.05s: VA1NSICCHOI44M240120171845.wav
# Processed in 0.03s: VO2NSICCHOI44M240120171849.wav
# Processed in 0.10s: VE1sncihcio44M1606161721.wav
# Processed in 0.29s: PR1NSICCHOI44M240120171851.wav
# Processed in 0.05s: D1sncihcio44M1606161719.wav
# Processed in 0.34s: FB1sncihcio44M1606161728.wav
# Processed in 0.18s: FB1NSICCHOI44M240120171852.wav
# Processed in 0.06s: VE1NSICCHOI44M240120171847.wav
# Processed in 0.05s: VE2sncihcio44M1606161722.wav
# Processed in 0.05s: VA2sncihcio44M1606161721.wav
# Processed in 0.09s: VO1sncihcio44M1606161723.wav
# Processed in 0.36s: B1NSICCHOI44M240120171842.wav
# Processed in 0.03s: VE2NSICCHOI44M240120171847.wav
# Processed in 0.05s: VU1NSICCHOI44M240120171849.wav
# Processed in 0.05s: VI2sncihcio44M1606161722.wav
# Processed in 0.50s: PR1sncihcio44M1606161727.wav
# Processed in 0.59s: B1sncihcio44M1606161717.wav
# Processed in 0.03s: D1NSICCHOI44M240120171845.wav
# Processed in 0.02s: VU2NSICCHOI44M240120171850.wav
# Processed in 0.05s: VU2sncihcio44M1606161725.wav
# Processed in 0.05s: VI1NSICCHOI44M240120171848.wav
# Processed in 0.03s: VI2NSICCHOI44M240120171848.wav
# Processed in 0.03s: VA2NSICCHOI44M240120171846.wav
# Processed in 0.08s: VU1sncihcio44M1606161724.wav
# Processed in 0.11s: VA1sncihcio44M1606161720.wav
# Processed in 0.05s: VO2sncihcio44M1606161723.wav
# Processed in 0.04s: VO1NSICCHOI44M240120171848.wav
# Processed in 0.07s: VI1sncihcio44M1606161722.wav
# Processed in 0.10s: VE2rriovbie49M2605161846.wav
# Processed in 0.08s: VU1rriovbie49M2605161849.wav
# Processed in 0.10s: VI1rriovbie49M2605161847.wav
# Processed in 0.03s: D2RROIBVEI49M240120171903.wav
# Processed in 0.47s: B2rriovbie49M2605161842.wav
# Processed in 0.03s: VI2RROIBVEI49M240120171909.wav
# Processed in 0.27s: FB1rriovbie49M2605161855.wav
# Processed in 0.08s: VI1RROIBVEI49M240120171908.wav
# Processed in 0.08s: VE1RROIBVEI49M240120171906.wav
# Processed in 0.06s: VA2rriovbie49M2605161845.wav
# Processed in 0.41s: PR1rriovbie49M2605161853.wav
# Processed in 0.12s: VO2rriovbie49M2605161849.wav
# Processed in 0.08s: VA1RROIBVEI49M240120171904.wav
# Processed in 0.08s: VO1RROIBVEI49M240120171910.wav
# Processed in 0.04s: D1rriovbie49M2605161843.wav
# Processed in 0.62s: B1rriovbie49M2605161841.wav
# Processed in 0.32s: B2RROIBVEI49M240120171902.wav
# Processed in 0.03s: VO2RROIBVEI49M240120171910.wav
# Processed in 0.03s: VU2RROIBVEI49M240120171911.wav
# Processed in 0.43s: B1RROIBVEI49M240120171859.wav
# Processed in 0.08s: VI2rriovbie49M2605161848.wav
# Processed in 0.10s: VU2rriovbie49M2605161850.wav
# Processed in 0.10s: VE1rriovbie49M2605161846.wav
# Processed in 0.03s: D1RROIBVEI49M240120171903.wav
# Processed in 0.26s: PR1RROIBVEI49M240120171913.wav
# Processed in 0.03s: VA2RROIBVEI49M240120171905.wav
# Processed in 0.04s: D2rriovbie49M2605161843.wav
# Processed in 0.06s: VU1RROIBVEI49M240120171911.wav
# Processed in 0.03s: VE2RROIBVEI49M240120171907.wav
# Processed in 0.18s: FB1RROIBVEI49M240120171914.wav
# Processed in 0.09s: VO1rriovbie49M2605161848.wav
# Processed in 0.12s: VA1rriovbie49M2605161845.wav
# Processed in 0.08s: VI1ABNINSAC46F240120171801.wav
# Processed in 0.36s: B1ABNINSAC46F240120171753.wav
# Processed in 0.03s: D2ABNINSAC46F240120171756.wav
# Processed in 0.03s: D1ABNINSAC46F240120171756.wav
# Processed in 0.03s: VE2ABNINSAC46F240120171801.wav
# Processed in 0.03s: VU2ABNINSAC46F240120171804.wav
# Processed in 0.06s: VE1ABNINSAC46F240120171800.wav
# Processed in 0.25s: B2ABNINSAC46F240120171755.wav
# Processed in 0.03s: VO2ABNINSAC46F240120171803.wav
# Processed in 0.13s: FB1ABNINSAC46F240120171808.wav
# Processed in 0.06s: VA1ABNINSAC46F240120171758.wav
# Processed in 0.27s: PR1ABNINSAC46F240120171807.wav
# Processed in 0.03s: VI2ABNINSAC46F240120171802.wav
# Processed in 0.06s: VO1ABNINSAC46F240120171802.wav
# Processed in 0.03s: VA2ABNINSAC46F240120171759.wav
# Processed in 0.07s: VU1ABNINSAC46F240120171804.wav
# Processed in 0.03s: D1NMIICNOO52M100220171135.wav
# Processed in 0.03s: VU2NMIICNOO52M100220171142.wav
# Processed in 0.03s: VA2NMIICNOO52M100220171137.wav
# Processed in 0.03s: VO2NMIICNOO52M100220171140.wav
# Processed in 0.84s: B1NMIICNOO52M100220171134.wav
# Processed in 0.04s: VI1NMIICNOO52M100220171139.wav
# Processed in 0.02s: VE1NMIICNOO52M100220171138.wav
# Processed in 0.74s: PR1NMIICNOO52M100220171146.wav
# Processed in 0.02s: VA1NMIICNOO52M100220171136.wav
# Processed in 0.02s: VI2NMIICNOO52M100220171140.wav
# Processed in 0.04s: VU1NMIICNOO52M100220171141.wav
# Processed in 0.04s: VO1NMIICNOO52M100220171140.wav
# Processed in 0.03s: VE2NMIICNOO52M100220171139.wav
# Processed in 0.03s: D2NMIICNOO52M100220171135.wav
# Processed in 0.04s: VO1DLAARCII37F100220171117.wav
# Processed in 0.06s: VU1DLAARCII37F100220171119.wav
# Processed in 0.03s: VU2DLAARCII37F100220171119.wav
# Processed in 0.04s: VI1DLAARCII37F100220171116.wav
# Processed in 0.33s: FB1DLAARCII37F100220171125.wav
# Processed in 0.04s: VE1DLAARCII37F100220171115.wav
# Processed in 0.03s: VA2DLAARCII37F100220171114.wav
# Processed in 0.03s: VE2DLAARCII37F100220171115.wav
# Processed in 0.84s: B1DLAARCII37F100220171111.wav
# Processed in 0.03s: VO2DLAARCII37F100220171117.wav
# Processed in 0.03s: D1DLAARCII37F100220171113.wav
# Processed in 0.03s: VI2DLAARCII37F100220171117.wav
# Processed in 0.51s: PR1DLAARCII37F100220171123.wav
# Processed in 0.03s: D2DLAARCII37F100220171113.wav
# Processed in 0.06s: VA1DLAARCII37F100220171114.wav
# Processed in 0.03s: VO2MBAUROIN45M100220171011.wav
# Processed in 0.43s: PR1MBAUROIN45M100220171014.wav
# Processed in 0.50s: B2MBAUROIN45M100220171006.wav
# Processed in 0.05s: VU1MBAUROIN45M100220171011.wav
# Processed in 0.03s: VI2MBAUROIN45M100220171010.wav
# Processed in 0.05s: VI1MBAUROIN45M100220171009.wav
# Processed in 0.06s: VO1MBAUROIN45M100220171010.wav
# Processed in 0.59s: B1MBAUROIN45M100220171003.wav
# Processed in 0.03s: VA2MBAUROIN45M100220171008.wav
# Processed in 0.03s: VU2MBAUROIN45M100220171011.wav
# Processed in 0.22s: FB1MBAUROIN45M100220171015.wav
# Processed in 0.07s: VA1MBAUROIN45M100220171007.wav
# Processed in 0.03s: VE2MBAUROIN45M100220171009.wav
# Processed in 0.05s: VE1MBAUROIN45M100220171009.wav
# Processed in 0.03s: D2MBAUROIN45M100220171006.wav
# Processed in 0.03s: D1MBAUROIN45M100220171006.wav
# Processed in 0.03s: VA2RLOABREE42M240120171947.wav
# Processed in 0.03s: VO2RLOABREE42M240120171951.wav
# Processed in 0.03s: VU2RLOABREE42M240120171952.wav
# Processed in 0.03s: D1RLOABREE42M240120171944.wav
# Processed in 0.07s: VU1RLOABREE42M240120171951.wav
# Processed in 0.32s: B1RLOABREE42M240120171942.wav
# Processed in 0.07s: VE1RLOABREE42M240120171948.wav
# Processed in 0.03s: VE2RLOABREE42M240120171949.wav
# Processed in 0.15s: FB1RLOABREE42M240120171955.wav
# Processed in 0.03s: VI2RLOABREE42M240120171950.wav
# Processed in 0.07s: VI1RLOABREE42M240120171949.wav
# Processed in 0.07s: VO1RLOABREE42M240120171950.wav
# Processed in 0.28s: PR1RLOABREE42M240120171954.wav
# Processed in 0.03s: D2RLOABREE42M240120171946.wav
# Processed in 0.30s: B2RLOABREE42M240120171944.wav
# Processed in 0.06s: VA1RLOABREE42M240120171947.wav
# Processed in 0.03s: VU2AGNUTGOL52F100220171054.wav
# Processed in 1.19s: B1AGNUTGOL52F100220171041.wav
# Processed in 0.37s: FB1AGNUTGOL52F100220171059.wav
# Processed in 0.05s: VA1AGNUTGOL52F100220171049.wav
# Processed in 0.02s: D2AGNUTGOL52F100220171046.wav
# Processed in 0.06s: VE1AGNUTGOL52F100220171050.wav
# Processed in 0.08s: VI1AGNUTGOL52F100220171051.wav
# Processed in 0.93s: B2AGNUTGOL52F100220171045.wav
# Processed in 0.03s: VO2AGNUTGOL52F100220171053.wav
# Processed in 0.03s: D1AGNUTGOL52F100220171046.wav
# Processed in 0.07s: VU1AGNUTGOL52F100220171054.wav
# Processed in 0.03s: VA2AGNUTGOL52F100220171049.wav
# Processed in 0.03s: VO1AGNUTGOL52F100220171052.wav
# Processed in 0.03s: VI2AGNUTGOL63F100220171052.wav
# Processed in 0.82s: PR1AGNUTGOL52F100220171057.wav
# Processed in 0.02s: VE2AGNUTGOL52F100220171049.wav
# Processed in 0.14s: VU2cdaopmoe67M2605161913.wav
# Processed in 0.40s: B2cdaopmoe67M2605161904.wav
# Processed in 0.11s: VO2cdaopmoe67M2605161912.wav
# Processed in 0.12s: VA1cdaopmoe67M2605161906.wav
# Processed in 0.12s: VA2cdaopmoe67M2605161907.wav
# Processed in 0.13s: VO1cdaopmoe67M2605161911.wav
# Processed in 0.14s: VI2cdaopmoe67M2605161911.wav
# Processed in 0.11s: VE1cdaopmoe67M2605161909.wav
# Processed in 0.14s: VU1cdaopmoe67M2605161913.wav
# Processed in 0.04s: D2cdaopmoe67M2605161905.wav
# Processed in 0.53s: B1cdaopmoe67M2605161902.wav
# Processed in 0.11s: VE2cdaopmoe67M2605161909.wav
# Processed in 0.04s: D1cdaopmoe67M2605161905.wav
# Processed in 0.13s: VI1cdaopmoe67M2605161910.wav
# Processed in 0.29s: PR1cdaopmoe67M2605161916.wav
# Processed in 0.17s: FB1cdaopmoe67M2605161917.wav
# Processed in 0.10s: VO1MCIICLHL46M240120171833.wav
# Processed in 0.10s: VE1MCIICLHL46M240120171830.wav
# Processed in 0.03s: VE2MCIICLHL46M240120171831.wav
# Processed in 0.03s: VA1MCIICLHL46M240120171830.wav
# Processed in 0.03s: VI2MCIICLHL46M240120171832.wav
# Processed in 0.18s: PR1MCIICLHL46M240120171836.wav
# Processed in 0.03s: VO2MCIICLHL46M240120171834.wav
# Processed in 0.08s: VA2MCIICLHL46M240120171829.wav
# Processed in 0.10s: VI1MCIICLHL46M240120171831.wav
# Processed in 0.24s: B2MCIICLHL46M240120171827.wav
# Processed in 0.26s: B1MCIICLHL46M240120171825.wav
# Processed in 0.11s: VU1MCIICLHL46M240120171834.wav
# Processed in 0.03s: D1MCIICLHL46M240120171828.wav
# Processed in 0.13s: FB1MCIICLHL46M240120171837.wav
# Processed in 0.03s: D2MCIICLHL46M240120171828.wav
# Processed in 0.03s: VU2MCIICLHL46M240120171835.wav
# Processed in 0.04s: D2cfaerlei54F2605161742.wav
# Processed in 0.09s: VE2cfaerlei54F2605161748.wav
# Processed in 0.08s: VU1cfaerlei54F2605161808.wav
# Processed in 0.22s: FB1cfaerlei54F2605161816.wav
# Processed in 0.49s: B1cfaerlei54F2605161738.wav
# Processed in 0.44s: PR1cfaerlei54F2605161815.wav
# Processed in 0.09s: VO2cfaerlei54F2605161756.wav
# Processed in 0.08s: VU2cfaerlei54F2605161810.wav
# Processed in 0.10s: VO1cfaerlei54F2605161755.wav
# Processed in 0.04s: D1cfaerlei54F2605161742.wav
# Processed in 0.10s: VI1cfaerlei54F2605161751.wav
# Processed in 0.41s: B2cfaerlei54F2605161740.wav
# Processed in 0.13s: VA1cfaerlei54F2605161745.wav
# Processed in 0.11s: VA2cfaerlei54F2605161745.wav
# Processed in 0.11s: VE1cfaerlei54F2605161747.wav
# Processed in 0.10s: VI2cfaerlei54F2605161752.wav
# Processed in 0.05s: D1ssacvhei61M1606161742.wav
# Processed in 0.15s: VA1ssacvhei61M1606161744.wav
# Processed in 0.05s: VE2ssacvhei61M1606161745.wav
# Processed in 0.24s: FB1ssacvhei61M1606161751.wav
# Processed in 0.05s: VU2ssacvhei61M1606161748.wav
# Processed in 0.42s: PR1ssacvhei61M1606161750.wav
# Processed in 0.05s: VA2ssacvhei61M1606161744.wav
# Processed in 0.14s: VI1ssacvhei61M1606161746.wav
# Processed in 0.14s: VO1ssacvhei61M1606161747.wav
# Processed in 0.50s: B2ssacvhei61M1606161741.wav
# Processed in 0.65s: B1ssacvhei61M1606161740.wav
# Processed in 0.05s: D2ssacvhei61M1606161742.wav
# Processed in 0.12s: VE1ssacvhei61M1606161745.wav
# Processed in 0.12s: VU1ssacvhei61M1606161748.wav
# Processed in 0.05s: VO2ssacvhei61M1606161747.wav
# Processed in 0.05s: VI2ssacvhei61M1606161746.wav
# Processed in 0.18s: VO1lloeroun56F2605161931.wav
# Processed in 0.17s: VO2lloeroun56F2605161931.wav
# Processed in 0.20s: VI1lloeroun56F2605161929.wav
# Processed in 0.14s: VE1lloeroun56F2605161927.wav
# Processed in 0.40s: B1lloeroun56F2605161922.wav
# Processed in 0.20s: FB1lloeroun56F2605161937.wav
# Processed in 0.20s: VU1lloeroun56F2605161932.wav
# Processed in 0.14s: VE2lloeroun56F2605161928.wav
# Processed in 0.16s: VU2lloeroun56F2605161933.wav
# Processed in 0.25s: VI2lloeroun56F2605161930.wav
# Processed in 0.38s: B2lloeroun56F2605161923.wav
# Processed in 0.15s: VA1lloeroun56F2605161926.wav
# Processed in 0.36s: PR1lloeroun56F2605161936.wav
# Processed in 0.04s: D1lloeroun56F2605161924.wav
# Processed in 0.04s: D2lloeroun56F2605161924.wav
# Processed in 0.16s: VA2lloeroun56F2605161927.wav
# Processed in 0.03s: D1VLIAT OP47M100220171317.wav
# Processed in 0.03s: VA2VLIAT OP47M100220171318.wav
# Processed in 0.06s: VO1VLIAT OP47M100220171320.wav
# Processed in 0.03s: VI2VLIAT OP47M100220171320.wav
# Processed in 0.03s: VE2VLIAT OP47M100220171319.wav
# Processed in 0.05s: VI1VLIAT OP47M100220171319.wav
# Processed in 0.05s: VE1VLIAT OP47M100220171319.wav
# Processed in 0.05s: VU1VLIAT OP47M100220171321.wav
# Processed in 0.03s: VU2VLIAT OP47M100220171321.wav
# Processed in 0.05s: VA1VLIAT OP47M100220171318.wav
# Processed in 0.55s: B1VLIAT OP47M100220171314.wav
# Processed in 0.34s: PR1VLIAT OP47M100220171323.wav
# Processed in 0.55s: B2VLIAT OP47M100220171316.wav
# Processed in 0.19s: FB1VLIAT OP47M100220171324.wav
# Processed in 0.03s: VO2VLIAT OP47M100220171320.wav
# Processed in 0.03s: D2VLIAT OP47M100220171317.wav
# Processed in 0.02s: VE1GMIAUSST39F100220171159.wav
# Processed in 0.03s: VO1GMIAUSST39F100220171200.wav
# Processed in 0.85s: B1GMIAUSST39F100220171156.wav
# Processed in 0.03s: D1GMIAUSST39F100220171157.wav
# Processed in 0.34s: FB1GMIAUSST39F100220171206.wav
# Processed in 0.02s: VI1GMIAUSST39F100220171200.wav
# Processed in 0.54s: PR1GMIAUSST39F100220171204.wav
# Processed in 0.02s: VU1GMIAUSST39F100220171200.wav
# Processed in 0.03s: D2GMIAUSST39F100220171158.wav
# Processed in 0.04s: VA1GMIAUSST39F100220171159.wav
# Processed in 0.49s: B1ubguot_t40M1606161755.wav
# Processed in 0.47s: B2ubguot_t40M1606161756.wav
# Processed in 0.05s: D2ubguot_t40M1606161758.wav
# Processed in 0.39s: PR1ubguot_t40M1606161806.wav
# Processed in 0.08s: VE1ubguot_t40M1606161800.wav
# Processed in 0.05s: D1ubguot_t40M1606161758.wav
# Processed in 0.05s: VU2ubguot_t40M1606161804.wav
# Processed in 0.25s: FB1ubguot_t40M1606161807.wav
# Processed in 0.05s: VA2ubguot_t40M1606161759.wav
# Processed in 0.08s: VI1ubguot_t40M1606161801.wav
# Processed in 0.08s: VO1ubguot_t40M1606161802.wav
# Processed in 0.05s: VO2ubguot_t40M1606161803.wav
# Processed in 0.08s: VU1ubguot_t40M1606161803.wav
# Processed in 0.05s: VI2ubguot_t40M1606161802.wav
# Processed in 0.05s: VE2ubguot_t40M1606161801.wav
# Processed in 0.09s: VA1ubguot_t40M1606161759.wav
# Processed in 0.12s: VO2rlouscsi77F2605161829.wav
# Processed in 0.09s: VI2rlouscsi77F2605161828.wav
# Processed in 0.05s: D2rlouscsi77F2605161823.wav
# Processed in 0.10s: VU2rlouscsi77F2605161830.wav
# Processed in 0.08s: VU1rlouscsi77F2605161830.wav
# Processed in 0.20s: FB1rlouscsi77F2605161834.wav
# Processed in 0.11s: VI1rlouscsi77F2605161827.wav
# Processed in 0.38s: B2rlouscsi77F2605161822.wav
# Processed in 0.04s: D1rlouscsi77F2605161822.wav
# Processed in 0.15s: VO1rlouscsi77F2605161828.wav
# Processed in 0.40s: PR1rlouscsi77F2605161834.wav
# Processed in 0.08s: VE1rlouscsi77F2605161826.wav
# Processed in 0.44s: B1rlouscsi77F2605161820.wav
# Processed in 0.08s: VA1rlouscsi77F2605161825.wav
# Processed in 0.10s: VE2rlouscsi77F2605161826.wav
# Processed in 0.09s: VA2rlouscsi77F2605161825.wav
# Processed in 0.23s: VE1lbuairgo52M1606161815.wav
# Processed in 0.41s: B1lbuairgo52M1606161810.wav
# Processed in 0.05s: VI2lbuairgo52M1606161816.wav
# Processed in 0.29s: FB1lbuairgo52M1606161825.wav
# Processed in 0.05s: VA2lbuairgo52M1606161814.wav
# Processed in 0.20s: VA1lbuairgo52M1606161813.wav
# Processed in 0.05s: D2lbuairgo52M1606161812.wav
# Processed in 0.38s: B2lbuairgo52M1606161811.wav
# Processed in 0.05s: VE2lbuairgo52M1606161815.wav
# Processed in 0.30s: PR1lbuairgo52M1606161824.wav
# Processed in 0.05s: VU2lbuairgo52M1606161820.wav
# Processed in 0.21s: VU1lbuairgo52M1606161819.wav
# Processed in 0.22s: VO1lbuairgo52M1606161817.wav
# Processed in 0.05s: D1lbuairgo52M1606161812.wav
# Processed in 0.05s: VO2lbuairgo52M1606161817.wav
# Processed in 0.20s: VI1lbuairgo52M1606161816.wav
# Processed in 0.03s: VA2GNIEOGVL47M100220171217.wav
# Processed in 0.07s: VO1GNIEOGVL47M100220171223.wav
# Processed in 0.03s: VE2GNIEOGVL47M100220171217.wav
# Processed in 0.09s: VA1GNIEOGVL47M100220171216.wav
# Processed in 0.07s: VI1GNIEOGVL47M100220171218.wav
# Processed in 0.03s: VI2GNIEOGVL47M100220171219.wav
# Processed in 0.03s: D2GNIEOGVL47M100220171215.wav
# Processed in 0.03s: VU2GNIEOGVL47M100220171224.wav
# Processed in 0.34s: B1GNIEOGVL47M100220171213.wav
# Processed in 0.14s: FB1GNIEOGVL47M100220171227.wav
# Processed in 0.24s: PR1GNIEOGVL47M100220171226.wav
# Processed in 0.31s: B2GNIEOGVL47M100220171214.wav
# Processed in 0.03s: D1GNIEOGVL47M100220171215.wav
# Processed in 0.03s: VO2GNIEOGVL47M100220171224.wav
# Processed in 0.08s: VE1GNIEOGVL47M100220171217.wav
# Processed in 0.05s: VU1GNIEOGVL47M100220171224.wav
# Processed in 0.10s: VO1GLIAUDLO50F100220171304.wav
# Processed in 0.40s: B2GLIAUDLO50F100220171259.wav
# Processed in 0.19s: FB1GLIAUDLO50F100220171308.wav
# Processed in 0.03s: D1GLIAUDLO50F100220171259.wav
# Processed in 0.11s: VE1GLIAUDLO50F100220171302.wav
# Processed in 0.41s: B1GLIAUDLO50F100220171257.wav
# Processed in 0.03s: VA2GLIAUDLO50F100220171301.wav
# Processed in 0.37s: PR1GLIAUDLO50F100220171307.wav
# Processed in 0.03s: D2GLIAUDLO50F100220171300.wav
# Processed in 0.03s: VI2GLIAUDLO50F100220171303.wav
# Processed in 0.10s: VI1GLIAUDLO50F100220171303.wav
# Processed in 0.03s: VU2GLIAUDLO50F100220171306.wav
# Processed in 0.10s: VU1GLIAUDLO50F100220171305.wav
# Processed in 0.10s: VA1GLIAUDLO50F100220171301.wav
# Processed in 0.03s: VO2GLIAUDLO50F100220171304.wav
# Processed in 0.03s: VE2GLIAUDLO50F100220171302.wav
#
# ✅ All files processed in 105.81 seconds

# %%
#CHUNKIFICATION OF ITALIAN DATA


import os
import time
from pydub import AudioSegment

# input_root = "/media/nigmu/android/Dataset(Linux)/Italian Silenced Dataset"
input_root = os.path.join("Dataset", "Italian Silenced Dataset")
output_root = os.path.join("Dataset", "Italian Chunked Dataset 100")
CHUNK_MS = 100
total_chunks = 0

def process_chunks(file_path, output_folder):
    global total_chunks
    start = time.time()
    
    # Load the audio file
    sound = AudioSegment.from_file(file_path, format="wav")
    file_name = os.path.splitext(os.path.basename(file_path))[0]

    
    chunk_dir = os.path.join(output_folder, file_name)
    os.makedirs(chunk_dir, exist_ok=True)
    

    file_chunks = 0
    for i in range(len(sound) // CHUNK_MS):
        chunk = sound[i * CHUNK_MS : (i + 1) * CHUNK_MS]
        
        if len(chunk) == CHUNK_MS:  # Ensure chunk is exactly 100ms
            chunk.export(os.path.join(chunk_dir, f"{file_name}_{i+1}.wav"), format="wav")
            file_chunks += 1
    
    total_chunks += file_chunks
    duration = time.time() - start
    print(f"Processed {os.path.basename(file_path)} ({file_chunks} chunks) in {duration:.2f}s")

total_start = time.time()


for group in ["HC", "PD"]:
    input_folder = os.path.join(input_root, group)
    output_folder = os.path.join(output_root, group)


    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".wav"):

                relative_path = os.path.relpath(root, input_folder)
                in_path = os.path.join(root, file)
                out_path = os.path.join(output_folder, relative_path)

                process_chunks(in_path, out_path)

total_duration = time.time() - total_start
print(f"\n✅ Total chunks created: {total_chunks}")
print(f"Total processing time: {total_duration:.2f} seconds")
# Out:
# Processed B1APNOTROC49M230320170926.wav (337 chunks) in 0.02s
# Processed VE1APNOTROC49M230320170929.wav (90 chunks) in 0.01s
# Processed VU2APNOTROC49M230320170932.wav (48 chunks) in 0.00s
# Processed VA1APNOTROC49M230320170928.wav (34 chunks) in 0.00s
# Processed D2APNOTROC49M230320170928.wav (31 chunks) in 0.00s
# Processed B2APNOTROC49M230320170927.wav (368 chunks) in 0.02s
# Processed VU1APNOTROC49M230320170932.wav (50 chunks) in 0.00s
# Processed D1APNOTROC49M230320170928.wav (26 chunks) in 0.00s
# Processed FB1APNOTROC49M230320170934.wav (150 chunks) in 0.01s
# Processed VA2APNOTROC49M230320170929.wav (34 chunks) in 0.00s
# Processed PR1APNOTROC49M230320170933.wav (156 chunks) in 0.01s
# Processed VI1APNOTROC49M230320170930.wav (44 chunks) in 0.00s
# Processed VI2APNOTROC49M230320170930.wav (58 chunks) in 0.00s
# Processed VE2APNOTROC49M230320170930.wav (54 chunks) in 0.00s
# Processed VO1APNOTROC49M230320170931.wav (55 chunks) in 0.00s
# Processed VO2APNOTROC49M230320170931.wav (49 chunks) in 0.00s
# Processed FB1GGIAORVG47F300320171218.wav (157 chunks) in 0.01s
# Processed VE1GGIAORVG47F300320171213.wav (52 chunks) in 0.00s
# Processed D2GGIAORVG47F300320171212.wav (18 chunks) in 0.00s
# Processed VI1GGIAORVG47F300320171214.wav (24 chunks) in 0.00s
# Processed VE1GLIAUDLO50F100220171302.wav (198 chunks) in 0.01s
# Processed B1GLIAUDLO50F100220171257.wav (548 chunks) in 0.03s
# Processed VA2GLIAUDLO50F100220171301.wav (57 chunks) in 0.00s
# Processed PR1GLIAUDLO50F100220171307.wav (330 chunks) in 0.02s
# Processed D2GLIAUDLO50F100220171300.wav (18 chunks) in 0.00s
# Processed VI2GLIAUDLO50F100220171303.wav (56 chunks) in 0.00s
# Processed VI1GLIAUDLO50F100220171303.wav (209 chunks) in 0.01s
# Processed VU2GLIAUDLO50F100220171306.wav (59 chunks) in 0.00s
# Processed VU1GLIAUDLO50F100220171305.wav (202 chunks) in 0.01s
# Processed VA1GLIAUDLO50F100220171301.wav (193 chunks) in 0.01s
# Processed VO2GLIAUDLO50F100220171304.wav (56 chunks) in 0.00s
# Processed VE2GLIAUDLO50F100220171302.wav (56 chunks) in 0.00s
#
# ✅ Total chunks created: 113266
# Total processing time: 7.05 seconds

# %%
# 1
# 
## ITALIAN RGB SPECTROGRAM DATA GENERATION 496x200


# import os
# import time
# import gc
# import librosa
# import numpy as np
# import matplotlib
# matplotlib.use('Agg')
# import matplotlib.pyplot as plt
# from PIL import Image

# # Configure paths
# # input_root = "Dataset/Italian Chunked Dataset"
# # output_root = "Dataset/Italian Spectrogram Dataset"

# # input_root = r"/home/nigmu/Downloads/Italian Chunked Dataset"
# # output_root = r"/home/nigmu/NPersonal/Projects/SDP/nigmu-parkinsons_disease_prediction/Dataset/Italian RGB Spectrogram Dataset"

# input_root = os.path.join("Dataset", "Italian Chunked Dataset")
# output_root =  os.path.join("Dataset", "Italian RGB Spectrogram Dataset")


# checkpoint_file = "processed_files.txt"

# # Load previously processed files
# processed_files_set = set()
# if os.path.exists(checkpoint_file):
#     with open(checkpoint_file, "r") as f:
#         processed_files_set = set(line.strip() for line in f)

# def save_checkpoint(file_path):
#     """Append a processed file to the checkpoint file."""
#     with open(checkpoint_file, "a") as f:
#         f.write(file_path + "\n")

# def generate_parkinsons_spectrogram(audio_path, save_path):
#     """Generate and save spectrogram images."""
#     y, sr = librosa.load(audio_path, sr=16000, mono=True)

#     mel_spec = librosa.feature.melspectrogram(
#         y=y, sr=sr, n_fft=512, hop_length=64, n_mels=64, fmax=4000, power=1.0
#     )

#     mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

#     fig = plt.figure(figsize=(3.2, 1.3), dpi=200)
#     ax = fig.add_subplot(111)

#     # plt.imshow(norm_spec, aspect='auto', cmap='gray', origin='lower')
#     plt.imshow(norm_spec, aspect='auto', cmap='inferno', origin='lower')

#     ax.axis('off')

#     temp_path = save_path + "_tmp.png"
#     plt.savefig(temp_path, bbox_inches='tight', pad_inches=0, format='png')

#     # 🔄 Convert RGBA to RGB
#     img = Image.open(temp_path).convert("RGB")
#     img.save(save_path)
#     os.remove(temp_path)  # Clean up


    

#     plt.close(fig)

# # Start time tracking
# start_time = time.time()

# # Get total number of files first
# total_files = sum(
#     len(files) for group in ["HC", "PD"] 
#     for _, _, files in os.walk(os.path.join(input_root, group)) if any(f.endswith('.wav') for f in files)
# )
# processed_files = len(processed_files_set)

# print(f"🔄 Processing {total_files} files... (Resuming from last checkpoint)")

# # Process both HC and PD folders
# for group in ["HC", "PD"]:
#     input_folder = os.path.join(input_root, group)
#     output_folder = os.path.join(output_root, group)

#     for root, _, files in os.walk(input_folder):
#         for file in files:
#             if file.lower().endswith(".wav"):
#                 in_path = os.path.join(root, file)
#                 out_dir = os.path.join(output_folder, os.path.relpath(root, input_folder))
#                 os.makedirs(out_dir, exist_ok=True)
#                 out_path = os.path.join(out_dir, f"{os.path.splitext(file)[0]}.png")

#                 # Skip if already processed
#                 if in_path in processed_files_set:
#                     continue

#                 file_start_time = time.time()

#                 generate_parkinsons_spectrogram(in_path, out_path)

#                 # Save progress
#                 save_checkpoint(in_path)
#                 processed_files += 1

#                 elapsed_time = time.time() - start_time
#                 time_per_image = elapsed_time / processed_files
#                 remaining_files = total_files - processed_files
#                 estimated_remaining_time = remaining_files * time_per_image

#                 print(
#                     f"✅ Processed {processed_files}/{total_files} files | "
#                     f"Time per image: {time_per_image:.2f}s | "
#                     f"Remaining: {remaining_files} files (~{estimated_remaining_time:.2f}s left)", end='\r'
#                 )

# # Final statistics
# total_time = time.time() - start_time
# print(f"\n✅ Success! Created {processed_files} spectrogram images in {total_time:.2f}s")

# %%
# 2
# 
#ITALIAN RGB SPECTROGRAM DATA GENERATION 224x224 Natural


# import os
# import time
# import gc
# import librosa
# import numpy as np
# import matplotlib
# matplotlib.use('Agg')
# import matplotlib.pyplot as plt
# from PIL import Image

# # Configure paths
# # input_root = "Dataset/Italian Chunked Dataset"
# # output_root = "Dataset/Italian Spectrogram Dataset"

# # input_root = r"/home/nigmu/Downloads/Italian Chunked Dataset"
# # output_root = r"/home/nigmu/NPersonal/Projects/SDP/nigmu-parkinsons_disease_prediction/Dataset/Italian RGB Spectrogram Dataset"

# input_root = os.path.join("Dataset", "Italian Chunked Dataset 689")
# output_root =  os.path.join("Dataset", "Italian RGB Spectrogram Dataset 2")


# checkpoint_file = "processed_files.txt"

# # Load previously processed files
# processed_files_set = set()
# if os.path.exists(checkpoint_file):
#     with open(checkpoint_file, "r") as f:
#         processed_files_set = set(line.strip() for line in f)

# def save_checkpoint(file_path):
#     """Append a processed file to the checkpoint file."""
#     with open(checkpoint_file, "a") as f:
#         f.write(file_path + "\n")

# def generate_exact_spectrogram(audio_path, save_path):
#     """Generate an exact 224x224 spectrogram from a trimmed 0.689s audio segment"""
#     target_samples = 11024
#     sr = 16000

#     # Load audio
#     y, _ = librosa.load(audio_path, sr=sr, mono=True)

#     # Trim or pad audio to exact size
#     if len(y) > target_samples:
#         y = y[:target_samples]
#     elif len(y) < target_samples:
#         y = np.pad(y, (0, target_samples - len(y)))

#     # Create Mel-spectrogram
#     mel_spec = librosa.feature.melspectrogram(
#         y=y, sr=sr, 
#         n_fft=320, 
#         hop_length=48,
#         n_mels=128, 
#         fmax=4000, 
#         power=1.4
#     )

#     # Normalize and convert to image
#     mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

#     # Resize to 224x224 without padding or data loss
#     from PIL import Image
#     img_array = np.flipud(norm_spec) * 255
#     img = Image.fromarray(img_array).convert("L").resize((224, 224), Image.BICUBIC)

#     # Convert to RGB image using inferno colormap
#     cmap = matplotlib.colormaps['inferno']
#     # rgba_array = cmap(np.flipud(norm_spec), bytes=True)
#     rgba_array = cmap(np.array(img)/255.0, bytes=True)
#     Image.fromarray(rgba_array).convert("RGB").save(save_path)
#     print("Spectrogram shape:", mel_spec.shape)  # → (128, ~224)

# # Start time tracking
# start_time = time.time()

# # Get total number of files first
# total_files = sum(
#     len(files) for group in ["HC", "PD"] 
#     for _, _, files in os.walk(os.path.join(input_root, group)) if any(f.endswith('.wav') for f in files)
# )
# processed_files = len(processed_files_set)

# print(f"🔄 Processing {total_files} files... (Resuming from last checkpoint)")

# # Process both HC and PD folders
# for group in ["HC", "PD"]:
#     input_folder = os.path.join(input_root, group)
#     output_folder = os.path.join(output_root, group)

#     for root, _, files in os.walk(input_folder):
#         for file in files:
#             if file.lower().endswith(".wav"):
#                 in_path = os.path.join(root, file)
#                 out_dir = os.path.join(output_folder, os.path.relpath(root, input_folder))
#                 os.makedirs(out_dir, exist_ok=True)
#                 out_path = os.path.join(out_dir, f"{os.path.splitext(file)[0]}.png")

#                 # Skip if already processed
#                 if in_path in processed_files_set:
#                     continue

#                 file_start_time = time.time()

#                 generate_exact_spectrogram(in_path, out_path)

#                 # Save progress
#                 save_checkpoint(in_path)
#                 processed_files += 1

#                 elapsed_time = time.time() - start_time
#                 time_per_image = elapsed_time / processed_files
#                 remaining_files = total_files - processed_files
#                 estimated_remaining_time = remaining_files * time_per_image

#                 print(
#                     f"✅ Processed {processed_files}/{total_files} files | "
#                     f"Time per image: {time_per_image:.2f}s | "
#                     f"Remaining: {remaining_files} files (~{estimated_remaining_time:.2f}s left)", end='\r'
#                 )

# # Final statistics
# total_time = time.time() - start_time
# print(f"\n✅ Success! Created {processed_files} spectrogram images in {total_time:.2f}s")

# %%
# 3
# Almost perfect shape by default
#
import os
import time
import gc
from PIL import Image
import numpy as np
import librosa
import librosa.display
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
def traverse_audio_files(input_root, groups=("HC", "PD"), file_extension=".wav"):
    """Traverse through input_root and yield all audio file paths."""
    for group in groups:
        group_folder = os.path.join(input_root, group)
        for root, _, files in os.walk(group_folder):
            for file in files:
                if file.lower().endswith(file_extension):
                    yield group, os.path.join(root, file)

def ensure_output_path(input_file_path, input_root, output_root, extension=".png"):
    """Generate the output path for a given input file path."""
    relative_path = os.path.relpath(input_file_path, input_root)
    output_path = os.path.join(output_root, os.path.splitext(relative_path)[0] + extension)
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    return output_path

def audio_to_spectrogram(audio_path, output_path):
    """Generate a 224x224 spectrogram image from 100ms of audio."""
    y, sr = librosa.load(audio_path, sr=None)
    
    expected_samples = int(0.1 * sr)
    
    if len(y) < expected_samples:
        y = np.pad(y, (0, expected_samples - len(y)), 'constant')
    else:
        y = y[:expected_samples]
    
    S = librosa.feature.melspectrogram(
        y=y, 
        sr=sr, 
        n_fft=1024, 
        # hop_length=64, 
        hop_length=30, 
        n_mels=224,
        fmin=0,
        fmax=4000
    )
    
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    fig, ax = plt.subplots(figsize=(224/100, 224/100), dpi=100)
    
    librosa.display.specshow(
        S_dB, 
        x_axis=None,
        y_axis=None,
        sr=sr,
        fmax=4000,
        ax=ax,
        cmap='inferno'
    )
    
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    plt.tight_layout(pad=0)
    plt.axis('off')
    
    temp_path = output_path + "_tmp.png"
    plt.savefig(temp_path, bbox_inches='tight', pad_inches=0)
    plt.close(fig)
    
    img = Image.open(temp_path).resize((224, 224), Image.LANCZOS).convert("RGB")
    img.save(output_path)
    
    os.remove(temp_path)

def process_and_track(files_iterator, input_root, output_root, generate_fn, checkpoint_file=None):
    """Process files, track progress and optionally resume from a checkpoint."""
    
    processed_files_set = set()
    if checkpoint_file and os.path.exists(checkpoint_file):
        with open(checkpoint_file, "r") as f:
            processed_files_set = set(line.strip() for line in f)
    
    def save_checkpoint(file_path):
        if checkpoint_file:
            with open(checkpoint_file, "a") as f:
                f.write(file_path + "\n")
    
    total_files = sum(1 for _ in files_iterator())
    processed_files = len(processed_files_set)
    
    print(f"🔄 Processing {total_files} files... (Resuming from last checkpoint)")
    
    start_time = time.time()
    for group, input_path in files_iterator():
        if input_path in processed_files_set:
            continue

        output_path = ensure_output_path(input_path, input_root, output_root)

        generate_fn(input_path, output_path)

        save_checkpoint(input_path)
        processed_files += 1

        # Progress tracking
        elapsed_time = time.time() - start_time
        time_per_image = elapsed_time / processed_files
        remaining_files = total_files - processed_files
        estimated_remaining_time = remaining_files * time_per_image

        print(
            f"✅ Processed {processed_files}/{total_files} files | "
            f"Time per image: {time_per_image:.2f}s | "
            f"Remaining: {remaining_files} files (~{estimated_remaining_time:.2f}s left)", end='\r'
        )
    
    total_time = time.time() - start_time
    print(f"\n✅ Success! Created {processed_files} spectrogram images in {total_time:.2f}s")

# =========================
# USAGE

# input_root = "/media/nigmu/android/Dataset(Linux)/Italian Chunked Dataset"
input_root = os.path.join("Dataset", "Italian Chunked Dataset 100")
output_root = os.path.join("Dataset", "Italian Spectrogram 30hopLength")
checkpoint_file = "processed_files_224x224.txt"

files_iterator = lambda: traverse_audio_files(input_root, groups=("HC", "PD"))

process_and_track(
    files_iterator,
    input_root=input_root,
    output_root=output_root
    generate_fn=audio_to_spectrogram,
    checkpoint_file=checkpoint_file
)
# Out:
# 🔄 Processing 113266 files... (Resuming from last checkpoint)
# ✅ Processed 113266/113266 files | Time per image: 0.05s | Remaining: 0 files (~0.00s left))))))))
# ✅ Success! Created 113266 spectrogram images in 5421.27s

# %%
#SILENCE REMOVAL TESTING



from pydub import AudioSegment
from pydub.silence import split_on_silence

def process_audio(input_file, output_file):
    sound = AudioSegment.from_file(input_file, format="wav")
    audio_chunks = split_on_silence(sound, min_silence_len=100, silence_thresh=-45, keep_silence=500)
    
    combined = sum(audio_chunks, AudioSegment.empty())
    combined.export(output_file, format="wav")
    print(f"✅ Processed: {output_file}")

# Example usage
process_audio("C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/Italian Dataset/PD/Anna B/B1ABNINSAC46F240120171753.wav", "silenced output.wav")

# %%
# CHUNKIFICATION TESTING


from pydub import AudioSegment
import os

def chunkify_audio(file_path, chunk_duration_ms, output_dir="chunks"):
    audio = AudioSegment.from_file(file_path)
    total_duration_ms = len(audio)
    
    # Force trimming to avoid extra partial chunk
    num_chunks = total_duration_ms // chunk_duration_ms
    trimmed_audio = audio[:num_chunks * chunk_duration_ms]

    print(f"Original duration: {total_duration_ms} ms")
    print(f"Chunk size: {chunk_duration_ms} ms")
    print(f"Number of full chunks: {num_chunks}")

    os.makedirs(output_dir, exist_ok=True)

    for i in range(num_chunks):
        start = i * chunk_duration_ms
        end = start + chunk_duration_ms
        chunk = trimmed_audio[start:end]
        chunk_path = os.path.join(output_dir, f"chunk_{i:04d}.wav")
        chunk.export(chunk_path, format="wav")
        

# Example usage:
chunkify_audio("S_ID04_pd_2_0_1.wav", chunk_duration_ms=689, output_dir="my_audio_chunks")
# Out:
# Original duration: 42139 ms
# Chunk size: 689 ms
# Number of full chunks: 61

# %%
import os
import numpy as np
import librosa
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from PIL import Image
import glob

def audio_to_spectrogram(audio_path, output_path):
    
    # Load audio file with a fixed duration of 100ms
    y, sr = librosa.load(audio_path, sr=None)
    
    # Calculate expected samples for 100ms
    expected_samples = int(0.1 * sr)
    
    # Ensure we have exactly 100ms of audio (pad or trim)
    if len(y) < expected_samples:
        # Pad with zeros if shorter
        y = np.pad(y, (0, expected_samples - len(y)), 'constant')
    else:
        # Trim if longer
        y = y[:expected_samples]
    
    # Create mel spectrogram
    # S = librosa.feature.melspectrogram(
    #     y=y, 
    #     sr=sr, 
    #     n_fft=n_fft,
    #     hop_length=hop_length,
    #     n_mels=n_mels,
    #     fmax=sr/2
    # )

    S = librosa.feature.melspectrogram(
        y=y, 
        sr=sr, 
        n_fft=1024,           # Increased for better frequency resolution
        hop_length=64,       # Smaller for smoother time transitions
        n_mels=224,           # More mel bands initially
        fmin=0,              # Focus on this frequency range
        fmax=4000
    )
    
    # Convert to dB scale
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    # Create figure with exact dimensions for 224x224 output
    fig, ax = plt.subplots(figsize=(224/100, 224/100), dpi=100)
    
    # Plot the mel spectrogram with inferno colormap
    img = librosa.display.specshow(
        S_dB, 
        x_axis='time',
        y_axis='mel', 
        sr=sr,
        fmax=4000,
        ax=ax,
        cmap='inferno'
    )
    
    # Remove axis labels and ticks to maximize spectrogram area
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
    plt.tight_layout(pad=0)
    plt.axis('off')
    
    # Save the spectrogram
    plt.savefig(output_path, bbox_inches='tight', pad_inches=0)
    plt.close(fig)
    
    # Resize to ensure exactly 224x224 if needed
    img = Image.open(output_path)
    # img = img.resize((224, 224), Image.LANCZOS)
    
    # Save the final resized image
    img.save(output_path)


audio_to_spectrogram(
    "chunk_0012.wav",
    "op/chunk_00122.png"
)
