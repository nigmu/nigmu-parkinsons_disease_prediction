# %%
# FOR NOISE REDUCTION


# import numpy as np
# import librosa
# import librosa.display
# import noisereduce as nr
# import matplotlib.pyplot as plt
# import sounddevice as sd
# import soundfile as sf

# # Load the audio file
# file_path = "test_audio.wav"
# y, sr = librosa.load(file_path, sr=None)  # Load with original sampling rate

# # Plot original waveform
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# librosa.display.waveshow(y, sr=sr)
# plt.title("Original Audio Waveform")
# plt.xlabel("Time (s)")
# plt.ylabel("Amplitude")

# # Noise reduction
# reduced_noise = nr.reduce_noise(y=y, sr=sr, prop_decrease=0.5) #prop_decrease sets reduction level, larger value means less noise and less quality but smaller value means more noise but more quality as well

# # Plot denoised waveform
# plt.subplot(1, 2, 2)
# librosa.display.waveshow(reduced_noise, sr=sr)
# plt.title("Denoised Audio Waveform")
# plt.xlabel("Time (s)")
# plt.ylabel("Amplitude")
# plt.tight_layout()
# plt.show()

# # ✅ Save the cleaned audio using soundfile (Fixes the error)
# sf.write("denoised_audio.wav", reduced_noise, sr)

# %%
# DOWNSAMPLIMG OF MDVR ORIGINAL DATASET


import os
import time
from pydub import AudioSegment

# Define relative paths
INPUT_ROOT = os.path.join("Dataset", "MDVR Original Dataset")
OUTPUT_ROOT = os.path.join("Dataset", "MDVR Downsampled Dataset")

# Create merged HC and PD folders
HC_FOLDER = os.path.join(OUTPUT_ROOT, "HC")
PD_FOLDER = os.path.join(OUTPUT_ROOT, "PD")
os.makedirs(HC_FOLDER, exist_ok=True)
os.makedirs(PD_FOLDER, exist_ok=True)

def downsample_audio(file_path, output_folder, prefix):
    """Downsamples an audio file to 16kHz and saves it with a prefix to prevent overwriting."""
    try:
        start = time.time()
        
        # Load audio
        sound = AudioSegment.from_file(file_path, format="wav")
        sound = sound.set_frame_rate(16000)  # Set sample rate to 16kHz
        
        # Save with "R_" or "S_" prefix to prevent overwriting
        file_name = os.path.basename(file_path)
        new_file_name = f"{prefix}_{file_name}"
        output_path = os.path.join(output_folder, new_file_name)
        
        sound.export(output_path, format="wav")

        duration = time.time() - start
        print(f"✅ Downsampled {file_name} → {new_file_name} in {duration:.2f}s")

    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")

# Start processing
total_start = time.time()
file_count = {"HC": 0, "PD": 0}

for subfolder, prefix in [("ReadText", "R"), ("SpontaneousDialogue", "S")]:  # Assign prefixes
    for group in ["HC", "PD"]:
        input_folder = os.path.join(INPUT_ROOT, subfolder, group)
        output_folder = HC_FOLDER if group == "HC" else PD_FOLDER  # Merge HC and PD

        if not os.path.exists(input_folder):
            print(f"❌ Skipping missing folder: {input_folder}")
            continue  # Skip if the folder doesn't exist

        for file in os.listdir(input_folder):
            if file.endswith(".wav"):
                in_path = os.path.join(input_folder, file)
                downsample_audio(in_path, output_folder, prefix)
                file_count[group] += 1  # Count processed files

# Print summary
total_duration = time.time() - total_start
print(f"\n✅ Downsampling complete in {total_duration:.2f} seconds")
print(f"📊 Total HC files: {file_count['HC']}, Total PD files: {file_count['PD']}")

# Print final structure
print("\n📁 Final Folder Structure:")
for root, dirs, files in os.walk(OUTPUT_ROOT):
    print(f"{root} ({len(files)} files)")
# Out:
# ✅ Downsampled ID00_hc_0_0_0.wav → R_ID00_hc_0_0_0.wav in 2.37s
# ✅ Downsampled ID01_hc_0_0_0.wav → R_ID01_hc_0_0_0.wav in 3.04s
# ✅ Downsampled ID03_hc_0_0_0.wav → R_ID03_hc_0_0_0.wav in 2.55s
# ✅ Downsampled ID05_hc_0_0_0.wav → R_ID05_hc_0_0_0.wav in 1.98s
# ✅ Downsampled ID08_hc_0_0_0.wav → R_ID08_hc_0_0_0.wav in 2.64s
# ✅ Downsampled ID09_hc_0_0_0.wav → R_ID09_hc_0_0_0.wav in 2.22s
# ✅ Downsampled ID10_hc_0_0_0.wav → R_ID10_hc_0_0_0.wav in 2.41s
# ✅ Downsampled ID11_hc_0_0_0.wav → R_ID11_hc_0_0_0.wav in 2.62s
# ✅ Downsampled ID12_hc_0_0_0.wav → R_ID12_hc_0_0_0.wav in 2.33s
# ✅ Downsampled ID14_hc_0_0_0.wav → R_ID14_hc_0_0_0.wav in 2.87s
# ✅ Downsampled ID15_hc_0_0_0.wav → R_ID15_hc_0_0_0.wav in 3.06s
# ✅ Downsampled ID19_hc_0_0_0.wav → R_ID19_hc_0_0_0.wav in 2.43s
# ✅ Downsampled ID21_hc_0_0_0.wav → R_ID21_hc_0_0_0.wav in 2.12s
# ✅ Downsampled ID22_hc_0_0_0.wav → R_ID22_hc_0_0_0.wav in 2.95s
# ✅ Downsampled ID23_hc_0_0_0.wav → R_ID23_hc_0_0_0.wav in 3.73s
# ✅ Downsampled ID25_hc_0_0_0.wav → R_ID25_hc_0_0_0.wav in 2.99s
# ✅ Downsampled ID26_hc_0_0_0.wav → R_ID26_hc_0_0_0.wav in 2.73s
# ✅ Downsampled ID28_hc_0_0_0.wav → R_ID28_hc_0_0_0.wav in 2.63s
# ✅ Downsampled ID31_hc_0_1_1.wav → R_ID31_hc_0_1_1.wav in 3.27s
# ✅ Downsampled ID35_hc_0_0_0.wav → R_ID35_hc_0_0_0.wav in 1.70s
# ✅ Downsampled ID36_hc_0_0_0.wav → R_ID36_hc_0_0_0.wav in 2.71s
# ✅ Downsampled ID02_pd_2_0_0.wav → R_ID02_pd_2_0_0.wav in 2.79s
# ✅ Downsampled ID04_pd_2_0_1.wav → R_ID04_pd_2_0_1.wav in 2.07s
# ✅ Downsampled ID06_pd_3_1_1.wav → R_ID06_pd_3_1_1.wav in 3.10s
# ✅ Downsampled ID07_pd_2_0_0.wav → R_ID07_pd_2_0_0.wav in 2.62s
# ✅ Downsampled ID13_pd_3_2_2.wav → R_ID13_pd_3_2_2.wav in 1.59s
# ✅ Downsampled ID16_pd_2_0_0.wav → R_ID16_pd_2_0_0.wav in 2.94s
# ✅ Downsampled ID17_pd_2_1_0.wav → R_ID17_pd_2_1_0.wav in 1.86s
# ✅ Downsampled ID18_pd_4_3_3.wav → R_ID18_pd_4_3_3.wav in 1.54s
# ✅ Downsampled ID20_pd_3_0_1.wav → R_ID20_pd_3_0_1.wav in 2.37s
# ✅ Downsampled ID24_pd_2_0_0.wav → R_ID24_pd_2_0_0.wav in 2.77s
# ✅ Downsampled ID27_pd_4_1_1.wav → R_ID27_pd_4_1_1.wav in 1.49s
# ✅ Downsampled ID29_pd_3_1_2.wav → R_ID29_pd_3_1_2.wav in 2.70s
# ✅ Downsampled ID30_pd_2_1_1.wav → R_ID30_pd_2_1_1.wav in 2.23s
# ✅ Downsampled ID32_pd_3_1_1.wav → R_ID32_pd_3_1_1.wav in 1.28s
# ✅ Downsampled ID33_pd_3_2_2.wav → R_ID33_pd_3_2_2.wav in 2.02s
# ✅ Downsampled ID34_pd_2_0_0.wav → R_ID34_pd_2_0_0.wav in 2.28s
# ✅ Downsampled ID00_hc_0_0_0.wav → S_ID00_hc_0_0_0.wav in 2.03s
# ✅ Downsampled ID01_hc_0_0_0.wav → S_ID01_hc_0_0_0.wav in 2.02s
# ✅ Downsampled ID03_hc_0_0_0.wav → S_ID03_hc_0_0_0.wav in 2.65s
# ✅ Downsampled ID05_hc_0_0_0.wav → S_ID05_hc_0_0_0.wav in 3.26s
# ✅ Downsampled ID08_hc_0_0_0.wav → S_ID08_hc_0_0_0.wav in 2.29s
# ✅ Downsampled ID09_hc_0_0_0.wav → S_ID09_hc_0_0_0.wav in 2.39s
# ✅ Downsampled ID10_hc_0_0_0.wav → S_ID10_hc_0_0_0.wav in 2.95s
# ✅ Downsampled ID11_hc_0_0_0.wav → S_ID11_hc_0_0_0.wav in 2.89s
# ✅ Downsampled ID12_hc_0_0_0.wav → S_ID12_hc_0_0_0.wav in 2.84s
# ✅ Downsampled ID14_hc_0_0_0.wav → S_ID14_hc_0_0_0.wav in 2.44s
# ✅ Downsampled ID15_hc_0_0_0.wav → S_ID15_hc_0_0_0.wav in 3.81s
# ✅ Downsampled ID19_hc_0_0_0.wav → S_ID19_hc_0_0_0.wav in 1.60s
# ✅ Downsampled ID21_hc_0_0_0.wav → S_ID21_hc_0_0_0.wav in 1.56s
# ✅ Downsampled ID22hc_0_0_0.wav → S_ID22hc_0_0_0.wav in 2.59s
# ✅ Downsampled ID23_hc_0_0_0.wav → S_ID23_hc_0_0_0.wav in 2.49s
# ✅ Downsampled ID25_hc_0_0_0.wav → S_ID25_hc_0_0_0.wav in 2.41s
# ✅ Downsampled ID26_hc_0_0_0.wav → S_ID26_hc_0_0_0.wav in 2.30s
# ✅ Downsampled ID28_hc_0_0_0.wav → S_ID28_hc_0_0_0.wav in 1.96s
# ✅ Downsampled ID31_hc_0_1_1.wav → S_ID31_hc_0_1_1.wav in 1.30s
# ✅ Downsampled ID35_hc_0_0_0.wav → S_ID35_hc_0_0_0.wav in 2.52s
# ✅ Downsampled ID36_hc_0_0_0.wav → S_ID36_hc_0_0_0.wav in 1.91s
# ✅ Downsampled ID02_pd_2_0_0.wav → S_ID02_pd_2_0_0.wav in 3.20s
# ✅ Downsampled ID04_pd_2_0_1.wav → S_ID04_pd_2_0_1.wav in 2.47s
# ✅ Downsampled ID06_pd_3_1_1.wav → S_ID06_pd_3_1_1.wav in 2.16s
# ✅ Downsampled ID07_pd_2_0_0.wav → S_ID07_pd_2_0_0.wav in 3.52s
# ✅ Downsampled ID13_pd_3_2_2.wav → S_ID13_pd_3_2_2.wav in 3.46s
# ✅ Downsampled ID16_pd_2_0_0.wav → S_ID16_pd_2_0_0.wav in 2.72s
# ✅ Downsampled ID17_pd_2_1_0.wav → S_ID17_pd_2_1_0.wav in 2.59s
# ✅ Downsampled ID20_pd_3_0_1.wav → S_ID20_pd_3_0_1.wav in 1.88s
# ✅ Downsampled ID24_pd_2_0_0.wav → S_ID24_pd_2_0_0.wav in 2.43s
# ✅ Downsampled ID27_pd_4_1_1.wav → S_ID27_pd_4_1_1.wav in 2.97s
# ✅ Downsampled ID29_pd_3_1_2.wav → S_ID29_pd_3_1_2.wav in 2.48s
# ✅ Downsampled ID30_pd_2_1_1.wav → S_ID30_pd_2_1_1.wav in 2.29s
# ✅ Downsampled ID32_pd_3_1_1.wav → S_ID32_pd_3_1_1.wav in 1.79s
# ✅ Downsampled ID33_pd_3_2_2.wav → S_ID33_pd_3_2_2.wav in 2.14s
# ✅ Downsampled ID34_pd_2_0_0.wav → S_ID34_pd_2_0_0.wav in 2.09s
#
# ✅ Downsampling complete in 179.48 seconds
# 📊 Total HC files: 42, Total PD files: 31
#
# 📁 Final Folder Structure:
# Dataset\MDVR Downsampled Dataset (0 files)
# Dataset\MDVR Downsampled Dataset\HC (42 files)
# Dataset\MDVR Downsampled Dataset\PD (31 files)

# %%
# DOWNSAMPLING OF ITALIAN DATASET


#IT'S ALREADY OF 16kHz

# %%
import os
import time
from pydub import AudioSegment
from pydub.silence import split_on_silence

# Define dataset paths
INPUT_ROOT = os.path.join("Dataset", "MDVR Downsampled Dataset")
OUTPUT_ROOT = os.path.join("Dataset", "MDVR Silenced Dataset")

def process_audio(file_path, output_path):
    """Removes silence from an audio file and saves it in the same structure."""
    start = time.time()

    sound = AudioSegment.from_file(file_path, format="wav")

    # Split on silence
    audio_chunks = split_on_silence(
        sound, 
        min_silence_len=100, 
        silence_thresh=-40, 
        keep_silence=500
    )

    # Combine processed chunks
    combined = sum(audio_chunks, AudioSegment.empty()) if audio_chunks else sound  # Ensure non-empty output

    os.makedirs(os.path.dirname(output_path), exist_ok=True)  # Ensure output folder exists
    combined.export(output_path, format="wav")

    duration = time.time() - start
    print(f"✅ Processed {os.path.basename(file_path)} in {duration:.2f}s")

# Start processing
total_start = time.time()
total_files = 0

for group in ["HC", "PD"]:
    input_folder = os.path.join(INPUT_ROOT, group)
    output_folder = os.path.join(OUTPUT_ROOT, group)

    files = [f for f in os.listdir(input_folder) if f.endswith(".wav")]
    total_files += len(files)

    for file in files:
        in_path = os.path.join(input_folder, file)
        out_path = os.path.join(output_folder, file)
        
        process_audio(in_path, out_path)

# Print summary
total_duration = time.time() - total_start
print(f"\n✅ Silence removal complete. Total processing time: {total_duration:.2f} seconds")
print(f"📊 Total files processed: {total_files}")

# Print final structure
print("\n📁 Final Folder Structure:")
for root, dirs, files in os.walk(OUTPUT_ROOT):
    print(f"{root} ({len(files)} files)")
# Out:
# ✅ Processed R_ID00_hc_0_0_0.wav in 3.01s
# ✅ Processed R_ID01_hc_0_0_0.wav in 2.42s
# ✅ Processed R_ID03_hc_0_0_0.wav in 2.40s
# ✅ Processed R_ID05_hc_0_0_0.wav in 1.80s
# ✅ Processed R_ID08_hc_0_0_0.wav in 2.22s
# ✅ Processed R_ID09_hc_0_0_0.wav in 1.89s
# ✅ Processed R_ID10_hc_0_0_0.wav in 2.38s
# ✅ Processed R_ID11_hc_0_0_0.wav in 2.13s
# ✅ Processed R_ID12_hc_0_0_0.wav in 2.13s
# ✅ Processed R_ID14_hc_0_0_0.wav in 2.16s
# ✅ Processed R_ID15_hc_0_0_0.wav in 2.87s
# ✅ Processed R_ID19_hc_0_0_0.wav in 2.33s
# ✅ Processed R_ID21_hc_0_0_0.wav in 1.81s
# ✅ Processed R_ID22_hc_0_0_0.wav in 2.77s
# ✅ Processed R_ID23_hc_0_0_0.wav in 3.22s
# ✅ Processed R_ID25_hc_0_0_0.wav in 2.93s
# ✅ Processed R_ID26_hc_0_0_0.wav in 5.13s
# ✅ Processed R_ID28_hc_0_0_0.wav in 2.81s
# ✅ Processed R_ID31_hc_0_1_1.wav in 3.69s
# ✅ Processed R_ID35_hc_0_0_0.wav in 1.49s
# ✅ Processed R_ID36_hc_0_0_0.wav in 2.74s
# ✅ Processed S_ID00_hc_0_0_0.wav in 1.86s
# ✅ Processed S_ID01_hc_0_0_0.wav in 1.92s
# ✅ Processed S_ID03_hc_0_0_0.wav in 2.50s
# ✅ Processed S_ID05_hc_0_0_0.wav in 3.02s
# ✅ Processed S_ID08_hc_0_0_0.wav in 2.06s
# ✅ Processed S_ID09_hc_0_0_0.wav in 2.40s
# ✅ Processed S_ID10_hc_0_0_0.wav in 2.71s
# ✅ Processed S_ID11_hc_0_0_0.wav in 2.50s
# ✅ Processed S_ID12_hc_0_0_0.wav in 2.63s
# ✅ Processed S_ID14_hc_0_0_0.wav in 2.49s
# ✅ Processed S_ID15_hc_0_0_0.wav in 4.40s
# ✅ Processed S_ID19_hc_0_0_0.wav in 1.45s
# ✅ Processed S_ID21_hc_0_0_0.wav in 1.39s
# ✅ Processed S_ID22hc_0_0_0.wav in 2.32s
# ✅ Processed S_ID23_hc_0_0_0.wav in 2.46s
# ✅ Processed S_ID25_hc_0_0_0.wav in 2.30s
# ✅ Processed S_ID26_hc_0_0_0.wav in 2.07s
# ✅ Processed S_ID28_hc_0_0_0.wav in 1.82s
# ✅ Processed S_ID31_hc_0_1_1.wav in 1.26s
# ✅ Processed S_ID35_hc_0_0_0.wav in 2.22s
# ✅ Processed S_ID36_hc_0_0_0.wav in 1.90s
# ✅ Processed R_ID02_pd_2_0_0.wav in 2.68s
# ✅ Processed R_ID04_pd_2_0_1.wav in 2.10s
# ✅ Processed R_ID06_pd_3_1_1.wav in 3.44s
# ✅ Processed R_ID07_pd_2_0_0.wav in 2.82s
# ✅ Processed R_ID13_pd_3_2_2.wav in 1.65s
# ✅ Processed R_ID16_pd_2_0_0.wav in 3.28s
# ✅ Processed R_ID17_pd_2_1_0.wav in 2.04s
# ✅ Processed R_ID18_pd_4_3_3.wav in 1.62s
# ✅ Processed R_ID20_pd_3_0_1.wav in 2.41s
# ✅ Processed R_ID24_pd_2_0_0.wav in 2.50s
# ✅ Processed R_ID27_pd_4_1_1.wav in 1.44s
# ✅ Processed R_ID29_pd_3_1_2.wav in 2.61s
# ✅ Processed R_ID30_pd_2_1_1.wav in 2.40s
# ✅ Processed R_ID32_pd_3_1_1.wav in 1.15s
# ✅ Processed R_ID33_pd_3_2_2.wav in 2.03s
# ✅ Processed R_ID34_pd_2_0_0.wav in 2.21s
# ✅ Processed S_ID02_pd_2_0_0.wav in 3.44s
# ✅ Processed S_ID04_pd_2_0_1.wav in 2.47s
# ✅ Processed S_ID06_pd_3_1_1.wav in 1.95s
# ✅ Processed S_ID07_pd_2_0_0.wav in 3.72s
# ✅ Processed S_ID13_pd_3_2_2.wav in 3.61s
# ✅ Processed S_ID16_pd_2_0_0.wav in 2.55s
# ✅ Processed S_ID17_pd_2_1_0.wav in 2.42s
# ✅ Processed S_ID20_pd_3_0_1.wav in 1.65s
# ✅ Processed S_ID24_pd_2_0_0.wav in 2.29s
# ✅ Processed S_ID27_pd_4_1_1.wav in 2.69s
# ✅ Processed S_ID29_pd_3_1_2.wav in 2.32s
# ✅ Processed S_ID30_pd_2_1_1.wav in 2.09s
# ✅ Processed S_ID32_pd_3_1_1.wav in 1.66s
# ✅ Processed S_ID33_pd_3_2_2.wav in 1.86s
# ✅ Processed S_ID34_pd_2_0_0.wav in 1.93s
#
# ✅ Silence removal complete. Total processing time: 175.26 seconds
# 📊 Total files processed: 73
#
# 📁 Final Folder Structure:
# Dataset\MDVR Silenced Dataset (0 files)
# Dataset\MDVR Silenced Dataset\HC (42 files)
# Dataset\MDVR Silenced Dataset\PD (31 files)

# %%
# SILENCE REMOVAL FROM ITALIAN DATA


import os
import time
from pydub import AudioSegment
from pydub.silence import split_on_silence

# Input and output directories
input_root = r"C:\NPersonal\Projects\SDP\Prediction Stuff\Dataset\Italian Dataset"
output_root = r"C:\NPersonal\Projects\SDP\Prediction Stuff\Dataset\Italian Silenced Dataset"

def process_audio(file_path, output_path):
    start = time.time()
    sound = AudioSegment.from_file(file_path, format="wav")
    
    # Silence removal parameters
    audio_chunks = split_on_silence(
        sound, 
        min_silence_len=100,
        silence_thresh=-40,
        keep_silence=500
    )
    
    # Merge all chunks back together
    combined = AudioSegment.empty()
    for chunk in audio_chunks:
        combined += chunk
    
    # Create necessary output directories
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    
    # Export the processed file
    combined.export(output_path, format="wav")
    
    duration = time.time() - start
    print(f"Processed in {duration:.2f}s: {os.path.basename(file_path)}")

total_start = time.time()

# Process both HC and PD directories
for group in ["HC", "PD"]:
    input_folder = os.path.join(input_root, group)
    output_folder = os.path.join(output_root, group)

    # Walk through all subdirectories recursively
    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".wav"):
                # Get relative path to maintain folder structure
                relative_path = os.path.relpath(root, input_folder)
                in_path = os.path.join(root, file)
                out_path = os.path.join(output_folder, relative_path, file)
                
                process_audio(in_path, out_path)

total_duration = time.time() - total_start
print(f"\n✅ All files processed in {total_duration:.2f} seconds")
# Out:
# Processed in 1.46s: B1APGANRET55F170320171104.wav
# Processed in 0.99s: B2APGANRET55F170320171105.wav
# Processed in 0.10s: D1APGANRET55F170320171106.wav
# Processed in 0.11s: D2APGANRET55F170320171107.wav
# Processed in 0.51s: FB1APGANRET55F170320171115.wav
# Processed in 0.84s: PR1APGANRET55F170320171114.wav
# Processed in 0.16s: VA1APGANRET55F170320171107.wav
# Processed in 0.10s: VA2APGANRET55F170320171108.wav
# Processed in 0.16s: VE1APGANRET55F170320171109.wav
# Processed in 0.08s: VE2APGANRET55F170320171109.wav
# Processed in 0.14s: VI1APGANRET55F170320171109.wav
# Processed in 0.13s: VI2APGANRET55F170320171110.wav
# Processed in 0.20s: VO1APGANRET55F170320171111.wav
# Processed in 0.09s: VO2APGANRET55F170320171111.wav
# Processed in 0.15s: VU1APGANRET55F170320171112.wav
# Processed in 0.11s: VU2APGANRET55F170320171112.wav
# Processed in 0.50s: B1LBULCAAS94M100120171015.wav
# Processed in 0.50s: B2LBULCAAS94M100120171015.wav
# Processed in 0.61s: PR1LBULCAAS94M100120171015..wav
# Processed in 0.51s: B1AMULCAAS94M100120171016.wav
# Processed in 0.50s: B2LBULCAAS94M100120171016.wav
# Processed in 0.61s: PR1LBULCAAS94M100120171016.wav
# Processed in 0.70s: B1LBULCAAS94M100120171017.wav
# Processed in 0.55s: B2LBULCAAS94M100120171017.wav
# Processed in 0.63s: PR1LBULCAAS94M100120171017.wav
# Processed in 0.75s: B1ACNAGRER49F210320170916.wav
# Processed in 0.72s: B2ACNAGRER49F210320170919.wav
# Processed in 0.09s: D1ACNAGRER49F210320171134.wav
# Processed in 0.09s: D2ACNAGRER49F210320171135.wav
# Processed in 0.33s: FB1ACNAGRER49F210320170926.wav
# Processed in 0.68s: PR1ACNAGRER49F210320170925.wav
# Processed in 0.19s: VA1ACNAGRER49F210320170920.wav
# Processed in 0.15s: VA2ACNAGRER49F210320170920.wav
# Processed in 0.23s: VE1ACNAGRER49F210320170921.wav
# Processed in 0.10s: VE2ACNAGRER49F210320170921.wav
# Processed in 0.29s: VI1ACNAGRER49F210320170921.wav
# Processed in 0.10s: VI2ACNAGRER49F210320170922.wav
# Processed in 0.24s: VO1ACNAGRER49F210320170922.wav
# Processed in 0.09s: VO2ACNAGRER49F210320170923.wav
# Processed in 0.27s: VU1ACNAGRER49F210320170923.wav
# Processed in 0.08s: VU2ACNAGRER49F210320170923.wav
# Processed in 0.97s: B1AGNIGNEE54F230320171018.wav
# Processed in 0.98s: B2AGNIGNEE54F230320171019.wav
# Processed in 0.10s: D1AGNIGNEE54F230320171019.wav
# Processed in 0.10s: D2AGNIGNEE54F230320171020.wav
# Processed in 0.45s: FB1AGNIGNEE54F230320171025.wav
# Processed in 0.63s: PR1AGNIGNEE54F230320171024.wav
# Processed in 0.25s: VA1AGNIGNEE54F230320171020.wav
# Processed in 0.10s: VA2AGNIGNEE54F230320171021.wav
# Processed in 0.11s: VE1AGNIGNEE54F230320171021.wav
# Processed in 0.10s: VE2AGNIGNEE54F230320171021.wav
# Processed in 0.12s: VI1AGNIGNEE54F230320171021.wav
# Processed in 0.08s: VI2AGNIGNEE54F230320171022.wav
# Processed in 0.12s: VO1AGNIGNEE54F230320171022.wav
# Processed in 0.08s: VO2AGNIGNEE54F230320171022.wav
# Processed in 0.16s: VU1AGNIGNEE54F230320171022.wav
# Processed in 0.08s: VU2AGNIGNEE54F230320171023.wav
# Processed in 0.89s: B1APNITNOT56F230320170847.wav
# Processed in 0.71s: B2APNITNOT56F230320170849.wav
# Processed in 0.09s: D1APNITNOT56F230320170849.wav
# Processed in 0.09s: D2APNITNOT56F230320170850.wav
# Processed in 0.33s: FB1APNITNOT56F230320170857.wav
# Processed in 0.61s: PR1APNITNOT56F230320170856.wav
# Processed in 0.16s: VA1APNITNOT56F230320170850.wav
# Processed in 0.10s: VA2APNITNOT56F230320170851.wav
# Processed in 0.12s: VE1APNITNOT56F230320170851.wav
# Processed in 0.09s: VE2APNITNOT56F230320170852.wav
# Processed in 0.16s: VI1APNITNOT56F230320170852.wav
# Processed in 0.08s: VI2APNITNOT56F230320170853.wav
# Processed in 0.14s: VO1APNITNOT56F230320170854.wav
# Processed in 0.08s: VO2APNITNOT56F230320170854.wav
# Processed in 0.14s: VU1APNITNOT56F230320170855.wav
# Processed in 0.10s: VU2APNITNOT56F230320170855.wav
# Processed in 0.83s: B1ACNUTCOC40M230320171121.wav
# Processed in 0.80s: B2ACNUTCOC40M230320171123.wav
# Processed in 0.11s: D1ACNUTCOC40M230320171124.wav
# Processed in 0.10s: D2ACNUTCOC40M230320171124.wav
# Processed in 0.37s: FB1ACNUTCOC40M230320171130.wav
# Processed in 0.83s: PR1ACNUTCOC40M230320171129.wav
# Processed in 0.11s: VA1ACNUTCOC40M230320171125.wav
# Processed in 0.10s: VA2ACNUTCOC40M230320171125.wav
# Processed in 0.13s: VE1ACNUTCOC40M230320171126.wav
# Processed in 0.10s: VE2ACNUTCOC40M230320171126.wav
# Processed in 0.13s: VI1ACNUTCOC40M230320171126.wav
# Processed in 0.08s: VI2ACNUTCOC40M230320171126.wav
# Processed in 0.14s: VO1ACNUTCOC40M230320171127.wav
# Processed in 0.08s: VO2ACNUTCOC40M230320171127.wav
# Processed in 0.14s: VU1ACNUTCOC40M230320171128.wav
# Processed in 0.08s: VU2ACNUTCOC40M230320171128.wav
# Processed in 0.52s: B1LBULCAAS94M100120171053.wav
# Processed in 0.52s: B2LBULCAAS94M100120171053.wav
# Processed in 0.51s: PR1LBULCAAS94M100120171053.wav
# Processed in 0.49s: B1LBULCAAS94M100120171056.wav
# Processed in 0.53s: B2LBULCAAS94M100120171056.wav
# Processed in 0.58s: PR1LBULCAAS94M100120171056.wav
# Processed in 0.82s: B1BCRAISGS48F210320171002.wav
# Processed in 0.65s: B2BCRAISGS48F210320171004.wav
# Processed in 0.11s: D1BCRAISGS48F210320171004.wav
# Processed in 0.08s: D2BCRAISGS48F210320171005.wav
# Processed in 0.09s: D2LFEIOONR57F210320171125.wav
# Processed in 0.39s: FB1LFEIOONR57F210320171131.wav
# Processed in 0.58s: PR1LFEIOONR57F210320171130.wav
# Processed in 0.11s: VA1LFEIOONR57F210320171126.wav
# Processed in 0.08s: VA2LFEIOONR57F210320171126.wav
# Processed in 0.14s: VE1LFEIOONR57F210320171126.wav
# Processed in 0.10s: VE2LFEIOONR57F210320171127.wav
# Processed in 0.22s: VI1LFEIOONR57F210320171127.wav
# Processed in 0.10s: VI2LFEIOONR57F210320171127.wav
# Processed in 0.22s: VO1LFEIOONR57F210320171128.wav
# Processed in 0.08s: VO2LFEIOONR57F210320171128.wav
# Processed in 0.22s: VU1LFEIOONR57F210320171128.wav
# Processed in 0.10s: VU2LFEIOONR57F210320171128.wav
# Processed in 0.79s: B1GLIIUSSC57M210320171050.wav
# Processed in 0.71s: B2GLIIUSSC57M210320171051.wav
# Processed in 0.09s: D1GLIIUSSC57M210320171052.wav
# Processed in 0.10s: D2GLIIUSSC57M210320171052.wav
# Processed in 0.33s: FB1GLIIUSSC57M210320171058.wav
# Processed in 0.50s: PR1GLIIUSSC57M210320171057.wav
# Processed in 0.25s: VA1GLIIUSSC57M210320171052.wav
# Processed in 0.08s: VA2GLIIUSSC57M210320171053.wav
# Processed in 0.28s: VE1GLIIUSSC57M210320171053.wav
# Processed in 0.08s: VE2GLIIUSSC57M210320171053.wav
# Processed in 0.21s: VI1GLIIUSSC57M210320171054.wav
# Processed in 0.09s: VI2GLIIUSSC57M210320171054.wav
# Processed in 0.19s: VO1GLIIUSSC57M210320171055.wav
# Processed in 0.08s: VO2GLIIUSSC57M210320171055.wav
# Processed in 0.23s: VU1GLIIUSSC57M210320171055.wav
# Processed in 0.07s: VU2GLIIUSSC57M210320171056.wav
# Processed in 0.59s: B1LBULCAAS94M100120171063.wav
# Processed in 0.56s: B2LBULCAAS94M100120171063.wav
# Processed in 0.47s: PR1LBULCAAS94M100120171063.wav
# Processed in 0.76s: B1LPUUITGI41M230320171109.wav
# Processed in 0.70s: B2LPUUITGI41M230320171110.wav
# Processed in 0.10s: D1LPUUITGI41M230320171110.wav
# Processed in 0.10s: D2LPUUITGI41M230320171111.wav
# Processed in 0.40s: FB1LPUUITGI41M230320171116.wav
# Processed in 0.67s: PR1LPUUITGI41M230320171115.wav
# Processed in 0.17s: VA1LPUUITGI41M230320171111.wav
# Processed in 0.08s: VA2LPUUITGI41M230320171111.wav
# Processed in 0.16s: VE1LPUUITGI41M230320171112.wav
# Processed in 0.08s: VE2LPUUITGI41M230320171112.wav
# Processed in 0.17s: VI1LPUUITGI41M230320171113.wav
# Processed in 0.08s: VI2LPUUITGI41M230320171113.wav
# Processed in 0.14s: VO1LPUUITGI41M230320171113.wav
# Processed in 0.10s: VO2LPUUITGI41M230320171113.wav
# Processed in 0.17s: VU1LPUUITGI41M230320171114.wav
# Processed in 0.08s: VU2LPUUITGI41M230320171114.wav
# Processed in 0.77s: B1MPAERRIR56F300320171143.wav
# Processed in 0.72s: B2MPAERRIR56F300320171145.wav
# Processed in 0.09s: D1MPAERRIR56F300320171145.wav
# Processed in 0.08s: D2MPAERRIR56F300320171145.wav
# Processed in 0.39s: FB1MPAERRIR56F300320171151.wav
# Processed in 0.77s: PR1MPAERRIR56F300320171150.wav
# Processed in 0.09s: VA1MPAERRIR56F300320171146.wav
# Processed in 0.09s: VA2MPAERRIR56F300320171146.wav
# Processed in 0.17s: VE1MPAERRIR56F300320171147.wav
# Processed in 0.08s: VE2MPAERRIR56F300320171147.wav
# Processed in 0.19s: VI1MPAERRIR56F300320171147.wav
# Processed in 0.08s: VI2MPAERRIR56F300320171148.wav
# Processed in 0.17s: VO1MPAERRIR56F300320171148.wav
# Processed in 0.08s: VO2MPAERRIR56F300320171148.wav
# Processed in 0.25s: VU1MPAERRIR56F300320171149.wav
# Processed in 0.07s: VU2MPAERRIR56F300320171149.wav
# Processed in 0.80s: B1MGIACTHT49M210320170848.wav
# Processed in 0.73s: B2MGIACTHT49M210320170850.wav
# Processed in 0.10s: D1MGIACTHT49M210320170854.wav
# Processed in 0.10s: D2MGIACTHT49M210320170855.wav
# Processed in 0.36s: FB1MGIACTHT49M210320170904.wav
# Processed in 0.66s: PR1MGIACTHT49M210320170903.wav
# Processed in 0.28s: VA1MGIACTHT49M210320170855.wav
# Processed in 0.10s: VA2MGIACTHT49M210320170856.wav
# Processed in 0.27s: VE1MGIACTHT49M210320170856.wav
# Processed in 0.08s: VE2MGIACTHT49M210320170857.wav
# Processed in 0.24s: VI1MGIACTHT49M210320170859.wav
# Processed in 0.09s: VI2MGIACTHT49M210320170859.wav
# Processed in 0.19s: VO1MGIACTHT49M210320170859.wav
# Processed in 0.10s: VO2MGIACTHT49M210320170900.wav
# Processed in 0.18s: VU1MGIACTHT49M210320170900.wav
# Processed in 0.10s: VU2MGIACTHT49M210320170901.wav
# Processed in 0.90s: B1NPIICEOR42M020420171805.wav
# Processed in 0.85s: B2NPIICEOR42M020420171807.wav
# Processed in 0.09s: D1NPIICEOR42M020420171807.wav
# Processed in 0.08s: D2NPIICEOR42M020420171807.wav
# Processed in 0.38s: FB1NPIICEOR42M020420171814.wav
# Processed in 0.55s: PR1NPIICEOR42M020420171813.wav
# Processed in 0.25s: VA1NPIICEOR42M020420171808.wav
# Processed in 0.10s: VA2NPIICEOR42M020420171809.wav
# Processed in 0.22s: VE1NPIICEOR42M020420171810.wav
# Processed in 0.08s: VE2NPIICEOR42M020420171810.wav
# Processed in 0.25s: VI1NPIICEOR42M020420171811.wav
# Processed in 0.08s: VI2NPIICEOR42M020420171811.wav
# Processed in 0.21s: VO1NPIICEOR42M020420171811.wav
# Processed in 0.08s: VO2NPIICEOR42M020420171811.wav
# Processed in 0.29s: VU1NPIICEOR42M020420171812.wav
# Processed in 0.09s: VU2NPIICEOR42M020420171812.wav
# Processed in 0.58s: B1LBULCAAS94M100120171023.wav
# Processed in 0.62s: B2LBULCAAS94M100120171023.wav
# Processed in 0.69s: PR1LBULCAAS94M100120171023.wav
# Processed in 0.79s: B1APNOTROC49M230320170926.wav
# Processed in 0.75s: B2APNOTROC49M230320170927.wav
# Processed in 0.10s: D1APNOTROC49M230320170928.wav
# Processed in 0.08s: D2APNOTROC49M230320170928.wav
# Processed in 0.33s: FB1APNOTROC49M230320170934.wav
# Processed in 0.45s: PR1APNOTROC49M230320170933.wav
# Processed in 0.14s: VA1APNOTROC49M230320170928.wav
# Processed in 0.08s: VA2APNOTROC49M230320170929.wav
# Processed in 0.25s: VE1APNOTROC49M230320170929.wav
# Processed in 0.09s: VE2APNOTROC49M230320170930.wav
# Processed in 0.27s: VI1APNOTROC49M230320170930.wav
# Processed in 0.08s: VI2APNOTROC49M230320170930.wav
# Processed in 0.17s: VO1APNOTROC49M230320170931.wav
# Processed in 0.09s: VO2APNOTROC49M230320170931.wav
# Processed in 0.25s: VU1APNOTROC49M230320170932.wav
# Processed in 0.10s: VU2APNOTROC49M230320170932.wav
# Processed in 0.69s: B1LBULCAAS94M100120171066.wav
# Processed in 0.64s: B2LBULCAAS94M100120171066.wav
# Processed in 0.58s: PR1LBULCAAS94M100120171066.wav
# Processed in 0.86s: B1LSUUIMGM48F230320171049.wav
# Processed in 0.74s: B2LSUUIMGM48F230320171050.wav
# Processed in 0.09s: D1LSUUIMGM48F230320171051.wav
# Processed in 0.09s: D2LSUUIMGM48F230320171051.wav
# Processed in 0.36s: FB1LSUUIMGM48F230320171059.wav
# Processed in 0.48s: PR1LSUUIMGM48F230320171058.wav
# Processed in 0.27s: VA1LSUUIMGM48F230320171053.wav
# Processed in 0.08s: VA2LSUUIMGM48F230320171053.wav
# Processed in 0.27s: VE1LSUUIMGM48F230320171054.wav
# Processed in 0.08s: VE2LSUUIMGM48F230320171054.wav
# Processed in 0.25s: VI1LSUUIMGM48F230320171055.wav
# Processed in 0.08s: VI2LSUUIMGM48F230320171055.wav
# Processed in 0.32s: VO1LSUUIMGM48F230320171056.wav
# Processed in 0.09s: VO2LSUUIMGM48F230320171056.wav
# Processed in 0.28s: VU1LSUUIMGM48F230320171057.wav
# Processed in 0.09s: VU2LSUUIMGM48F230320171057.wav
# Processed in 1.02s: B1TMEIRAEC54F230320171150.wav
# Processed in 0.81s: B2TMEIRAEC54F230320171152.wav
# Processed in 0.10s: D1TMEIRAEC54F230320171152.wav
# Processed in 0.09s: D2TMEIRAEC54F230320171152.wav
# Processed in 0.43s: FB1TMEIRAEC54F230320171158.wav
# Processed in 0.73s: PR1TMEIRAEC54F230320171157.wav
# Processed in 0.10s: VA1TMEIRAEC54F230320171153.wav
# Processed in 0.08s: VA2TMEIRAEC54F230320171153.wav
# Processed in 0.10s: VE1TMEIRAEC54F230320171154.wav
# Processed in 0.08s: VE2TMEIRAEC54F230320171154.wav
# Processed in 0.10s: VI1TMEIRAEC54F230320171154.wav
# Processed in 0.08s: VI2TMEIRAEC54F230320171154.wav
# Processed in 0.10s: VO1TMEIRAEC54F230320171155.wav
# Processed in 0.09s: VO2TMEIRAEC54F230320171155.wav
# Processed in 0.08s: VU1TMEIRAEC54F230320171155.wav
# Processed in 0.08s: VU2TMEIRAEC54F230320171155.wav
# Processed in 0.10s: D1VDIET AS47M210320170946.wav
# Processed in 0.11s: D2VDIET AS47M210320170946.wav
# Processed in 0.89s: PR1VDIETAS47M210320170948.wav
# Processed in 0.11s: VA1VDIET AS47M210320170942.wav
# Processed in 0.11s: VA2VDIET AS47M210320170943.wav
# Processed in 0.14s: VE1VDIET AS47M210320170943.wav
# Processed in 0.11s: VE2VDIET AS47M210320170944.wav
# Processed in 0.13s: VI1VDIET AS47M210320170944.wav
# Processed in 0.10s: VI2VDIET AS47M210320170944.wav
# Processed in 0.19s: VO1VDIET AS47M210320170945.wav
# Processed in 0.08s: VO2VDIET AS47M210320170945.wav
# Processed in 0.13s: VU1VDIET AS47M210320170945.wav
# Processed in 0.10s: VU2VDIET AS47M210320170945.wav
# Processed in 0.87s: B1VAILTFOO49M230320171029.wav
# Processed in 0.72s: B2VAILTFOO49M230320171030.wav
# Processed in 0.10s: D1VAILTFOO49M230320171030.wav
# Processed in 0.09s: D2VAILTFOO49M230320171031.wav
# Processed in 0.33s: FB1VAILTFOO49M230320171036.wav
# Processed in 0.57s: PR1VAILTFOO49M230320171035.wav
# Processed in 0.16s: VA1VAILTFOO49M230320171031.wav
# Processed in 0.10s: VA2VAILTFOO49M230320171031.wav
# Processed in 0.10s: VE1VAILTFOO49M230320171032.wav
# Processed in 0.08s: VE2VAILTFOO49M230320171032.wav
# Processed in 0.14s: VI1VAILTFOO49M230320171032.wav
# Processed in 0.10s: VI2VAILTFOO49M230320171033.wav
# Processed in 0.13s: VO1VAILTFOO49M230320171033.wav
# Processed in 0.08s: VO2VAILTFOO49M230320171033.wav
# Processed in 0.13s: VU1VAILTFOO49M230320171033.wav
# Processed in 0.08s: VU2VAILTFOO49M230320171034.wav
# Processed in 1.23s: B1VLIATFOO55M300320171237.wav
# Processed in 0.92s: B2VLIATFOO55M300320171238.wav
# Processed in 0.09s: D1VLIATFOO55M300320171244.wav
# Processed in 0.09s: D2VLIATFOO55M300320171244.wav
# Processed in 0.39s: FB1VLIATFOO55M300320171243.wav
# Processed in 0.65s: PR1VLIATFOO55M300320171241.wav
# Processed in 0.29s: VA1VLIATFOO55M300320171245.wav
# Processed in 0.08s: VA2VLIATFOO55M300320171245.wav
# Processed in 0.38s: VE1VLIATFOO55M300320171246.wav
# Processed in 0.08s: VE2VLIATFOO55M300320171246.wav
# Processed in 0.32s: VI1VLIATFOO55M300320171247.wav
# Processed in 0.09s: VI2VLIATFOO55M300320171247.wav
# Processed in 0.38s: VO1VLIATFOO55M300320171247.wav
# Processed in 0.10s: VO2VLIATFOO55M300320171248.wav
# Processed in 0.34s: VU1VLIATFOO55M300320171248.wav
# Processed in 0.09s: VU2VLIATFOO55M300320171249.wav
# Processed in 0.89s: B1ABNINSAC46F240120171753.wav
# Processed in 0.64s: B2ABNINSAC46F240120171755.wav
# Processed in 0.09s: D1ABNINSAC46F240120171756.wav
# Processed in 0.08s: D2ABNINSAC46F240120171756.wav
# Processed in 0.35s: FB1ABNINSAC46F240120171808.wav
# Processed in 0.72s: PR1ABNINSAC46F240120171807.wav
# Processed in 0.16s: VA1ABNINSAC46F240120171758.wav
# Processed in 0.09s: VA2ABNINSAC46F240120171759.wav
# Processed in 0.16s: VE1ABNINSAC46F240120171800.wav
# Processed in 0.10s: VE2ABNINSAC46F240120171801.wav
# Processed in 0.19s: VI1ABNINSAC46F240120171801.wav
# Processed in 0.10s: VI2ABNINSAC46F240120171802.wav
# Processed in 0.19s: VO1ABNINSAC46F240120171802.wav
# Processed in 0.10s: VO2ABNINSAC46F240120171803.wav
# Processed in 0.19s: VU1ABNINSAC46F240120171804.wav
# Processed in 0.10s: VU2ABNINSAC46F240120171804.wav
# Processed in 3.25s: B1AGNUTGOL52F100220171041.wav
# Processed in 2.51s: B2AGNUTGOL52F100220171045.wav
# Processed in 0.08s: D1AGNUTGOL52F100220171046.wav
# Processed in 0.06s: D2AGNUTGOL52F100220171046.wav
# Processed in 0.98s: FB1AGNUTGOL52F100220171059.wav
# Processed in 2.18s: PR1AGNUTGOL52F100220171057.wav
# Processed in 0.13s: VA1AGNUTGOL52F100220171049.wav
# Processed in 0.08s: VA2AGNUTGOL52F100220171049.wav
# Processed in 0.16s: VE1AGNUTGOL52F100220171050.wav
# Processed in 0.06s: VE2AGNUTGOL52F100220171049.wav
# Processed in 0.22s: VI1AGNUTGOL52F100220171051.wav
# Processed in 0.09s: VI2AGNUTGOL63F100220171052.wav
# Processed in 0.10s: VO1AGNUTGOL52F100220171052.wav
# Processed in 0.07s: VO2AGNUTGOL52F100220171053.wav
# Processed in 0.21s: VU1AGNUTGOL52F100220171054.wav
# Processed in 0.08s: VU2AGNUTGOL52F100220171054.wav
# Processed in 2.37s: B1DLAARCII37F100220171111.wav
# Processed in 0.08s: D1DLAARCII37F100220171113.wav
# Processed in 0.07s: D2DLAARCII37F100220171113.wav
# Processed in 0.88s: FB1DLAARCII37F100220171125.wav
# Processed in 1.35s: PR1DLAARCII37F100220171123.wav
# Processed in 0.17s: VA1DLAARCII37F100220171114.wav
# Processed in 0.09s: VA2DLAARCII37F100220171114.wav
# Processed in 0.12s: VE1DLAARCII37F100220171115.wav
# Processed in 0.08s: VE2DLAARCII37F100220171115.wav
# Processed in 0.12s: VI1DLAARCII37F100220171116.wav
# Processed in 0.08s: VI2DLAARCII37F100220171117.wav
# Processed in 0.12s: VO1DLAARCII37F100220171117.wav
# Processed in 0.08s: VO2DLAARCII37F100220171117.wav
# Processed in 0.17s: VU1DLAARCII37F100220171119.wav
# Processed in 0.08s: VU2DLAARCII37F100220171119.wav
# Processed in 1.57s: B1cdaopmoe67M2605161902.wav
# Processed in 1.16s: B2cdaopmoe67M2605161904.wav
# Processed in 0.11s: D1cdaopmoe67M2605161905.wav
# Processed in 0.11s: D2cdaopmoe67M2605161905.wav
# Processed in 0.49s: FB1cdaopmoe67M2605161917.wav
# Processed in 0.82s: PR1cdaopmoe67M2605161916.wav
# Processed in 0.37s: VA1cdaopmoe67M2605161906.wav
# Processed in 0.33s: VA2cdaopmoe67M2605161907.wav
# Processed in 0.29s: VE1cdaopmoe67M2605161909.wav
# Processed in 0.33s: VE2cdaopmoe67M2605161909.wav
# Processed in 0.35s: VI1cdaopmoe67M2605161910.wav
# Processed in 0.37s: VI2cdaopmoe67M2605161911.wav
# Processed in 0.36s: VO1cdaopmoe67M2605161911.wav
# Processed in 0.32s: VO2cdaopmoe67M2605161912.wav
# Processed in 0.37s: VU1cdaopmoe67M2605161913.wav
# Processed in 0.37s: VU2cdaopmoe67M2605161913.wav
# Processed in 1.40s: B1cfaerlei54F2605161738.wav
# Processed in 1.16s: B2cfaerlei54F2605161740.wav
# Processed in 0.11s: D1cfaerlei54F2605161742.wav
# Processed in 0.11s: D2cfaerlei54F2605161742.wav
# Processed in 0.62s: FB1cfaerlei54F2605161816.wav
# Processed in 1.31s: PR1cfaerlei54F2605161815.wav
# Processed in 0.37s: VA1cfaerlei54F2605161745.wav
# Processed in 0.33s: VA2cfaerlei54F2605161745.wav
# Processed in 0.31s: VE1cfaerlei54F2605161747.wav
# Processed in 0.23s: VE2cfaerlei54F2605161748.wav
# Processed in 0.28s: VI1cfaerlei54F2605161751.wav
# Processed in 0.27s: VI2cfaerlei54F2605161752.wav
# Processed in 0.27s: VO1cfaerlei54F2605161755.wav
# Processed in 0.24s: VO2cfaerlei54F2605161756.wav
# Processed in 0.22s: VU1cfaerlei54F2605161808.wav
# Processed in 0.22s: VU2cfaerlei54F2605161810.wav
# Processed in 0.92s: B1GMIAOSVI44M100220170942.wav
# Processed in 0.87s: B2GMIAOSVI44M100220170944.wav
# Processed in 0.08s: D1GMIAOSVI44M100220170945.wav
# Processed in 0.10s: D2GMIAOSVI44M100220170945.wav
# Processed in 0.52s: FB1GMIAOSVI44M100220170952.wav
# Processed in 0.70s: PR1GMIAOSVI44M100220170951.wav
# Processed in 0.11s: VA1GMIAOSVI44M100220170946.wav
# Processed in 0.08s: VA2GMIAOSVI44M100220170946.wav
# Processed in 0.13s: VE1GMIAOSVI44M100220170947.wav
# Processed in 0.08s: VE2GMIAOSVI44M100220170947.wav
# Processed in 0.13s: VI1GMIAOSVI44M100220170948.wav
# Processed in 0.08s: VI2GMIAOSVI44M100220170948.wav
# Processed in 0.14s: VO1GMIAOSVI44M100220170948.wav
# Processed in 0.10s: VO2GMIAOSVI44M100220170949.wav
# Processed in 0.11s: VU1GMIAOSVI44M100220170949.wav
# Processed in 0.08s: VU2GMIAOSVI44M100220170949.wav
# Processed in 0.90s: B1GNIEOGVL47M100220171213.wav
# Processed in 0.82s: B2GNIEOGVL47M100220171214.wav
# Processed in 0.08s: D1GNIEOGVL47M100220171215.wav
# Processed in 0.08s: D2GNIEOGVL47M100220171215.wav
# Processed in 0.38s: FB1GNIEOGVL47M100220171227.wav
# Processed in 0.64s: PR1GNIEOGVL47M100220171226.wav
# Processed in 0.24s: VA1GNIEOGVL47M100220171216.wav
# Processed in 0.07s: VA2GNIEOGVL47M100220171217.wav
# Processed in 0.21s: VE1GNIEOGVL47M100220171217.wav
# Processed in 0.09s: VE2GNIEOGVL47M100220171217.wav
# Processed in 0.22s: VI1GNIEOGVL47M100220171218.wav
# Processed in 0.07s: VI2GNIEOGVL47M100220171219.wav
# Processed in 0.21s: VO1GNIEOGVL47M100220171223.wav
# Processed in 0.08s: VO2GNIEOGVL47M100220171224.wav
# Processed in 0.16s: VU1GNIEOGVL47M100220171224.wav
# Processed in 0.08s: VU2GNIEOGVL47M100220171224.wav
# Processed in 1.13s: B1GLIAUDLO50F100220171257.wav
# Processed in 1.13s: B2GLIAUDLO50F100220171259.wav
# Processed in 0.08s: D1GLIAUDLO50F100220171259.wav
# Processed in 0.08s: D2GLIAUDLO50F100220171300.wav
# Processed in 0.48s: FB1GLIAUDLO50F100220171308.wav
# Processed in 0.98s: PR1GLIAUDLO50F100220171307.wav
# Processed in 0.26s: VA1GLIAUDLO50F100220171301.wav
# Processed in 0.07s: VA2GLIAUDLO50F100220171301.wav
# Processed in 0.27s: VE1GLIAUDLO50F100220171302.wav
# Processed in 0.08s: VE2GLIAUDLO50F100220171302.wav
# Processed in 0.27s: VI1GLIAUDLO50F100220171303.wav
# Processed in 0.08s: VI2GLIAUDLO50F100220171303.wav
# Processed in 0.27s: VO1GLIAUDLO50F100220171304.wav
# Processed in 0.08s: VO2GLIAUDLO50F100220171304.wav
# Processed in 0.27s: VU1GLIAUDLO50F100220171305.wav
# Processed in 0.09s: VU2GLIAUDLO50F100220171306.wav
# Processed in 0.70s: B1GPIUUGLL63F100220171020.wav
# Processed in 0.72s: B2GPIUUGLL63F100220171021.wav
# Processed in 0.10s: D1GPIUUGLL63F100220171022.wav
# Processed in 0.08s: D2GPIUUGLL63F100220171022.wav
# Processed in 0.38s: FB1GPIUUGLL63F100220171030.wav
# Processed in 0.73s: PR1GPIUUGLL63F100220171029.wav
# Processed in 0.17s: VA1GPIUUGLL63F100220171023.wav
# Processed in 0.08s: VA2GPIUUGLL63F100220171024.wav
# Processed in 0.35s: VE1GPIUUGLL63F100220171024.wav
# Processed in 0.08s: VE2GPIUUGLL63F100220171025.wav
# Processed in 0.32s: VI1GPIUUGLL63F100220171025.wav
# Processed in 0.08s: VI2GPIUUGLL63F100220171026.wav
# Processed in 0.21s: VO1GPIUUGLL63F100220171026.wav
# Processed in 0.08s: VO2GPIUUGLL63F100220171027.wav
# Processed in 0.22s: VU1GPIUUGLL63F100220171027.wav
# Processed in 0.10s: VU2GPIUUGLL63F100220171027.wav
# Processed in 2.45s: B1GMIAUSST39F100220171156.wav
# Processed in 0.09s: D1GMIAUSST39F100220171157.wav
# Processed in 0.08s: D2GMIAUSST39F100220171158.wav
# Processed in 0.89s: FB1GMIAUSST39F100220171206.wav
# Processed in 1.39s: PR1GMIAUSST39F100220171204.wav
# Processed in 0.12s: VA1GMIAUSST39F100220171159.wav
# Processed in 0.07s: VE1GMIAUSST39F100220171159.wav
# Processed in 0.05s: VI1GMIAUSST39F100220171200.wav
# Processed in 0.11s: VO1GMIAUSST39F100220171200.wav
# Processed in 0.05s: VU1GMIAUSST39F100220171200.wav
# Processed in 1.16s: B1lloeroun56F2605161922.wav
# Processed in 1.05s: B2lloeroun56F2605161923.wav
# Processed in 0.10s: D1lloeroun56F2605161924.wav
# Processed in 0.11s: D2lloeroun56F2605161924.wav
# Processed in 0.57s: FB1lloeroun56F2605161937.wav
# Processed in 1.02s: PR1lloeroun56F2605161936.wav
# Processed in 0.42s: VA1lloeroun56F2605161926.wav
# Processed in 0.41s: VA2lloeroun56F2605161927.wav
# Processed in 0.41s: VE1lloeroun56F2605161927.wav
# Processed in 0.38s: VE2lloeroun56F2605161928.wav
# Processed in 0.53s: VI1lloeroun56F2605161929.wav
# Processed in 0.67s: VI2lloeroun56F2605161930.wav
# Processed in 0.55s: VO1lloeroun56F2605161931.wav
# Processed in 0.51s: VO2lloeroun56F2605161931.wav
# Processed in 0.56s: VU1lloeroun56F2605161932.wav
# Processed in 0.42s: VU2lloeroun56F2605161933.wav
# Processed in 1.30s: B1rlouscsi77F2605161820.wav
# Processed in 1.11s: B2rlouscsi77F2605161822.wav
# Processed in 0.12s: D1rlouscsi77F2605161822.wav
# Processed in 0.13s: D2rlouscsi77F2605161823.wav
# Processed in 0.56s: FB1rlouscsi77F2605161834.wav
# Processed in 1.17s: PR1rlouscsi77F2605161834.wav
# Processed in 0.20s: VA1rlouscsi77F2605161825.wav
# Processed in 0.24s: VA2rlouscsi77F2605161825.wav
# Processed in 0.23s: VE1rlouscsi77F2605161826.wav
# Processed in 0.28s: VE2rlouscsi77F2605161826.wav
# Processed in 0.31s: VI1rlouscsi77F2605161827.wav
# Processed in 0.24s: VI2rlouscsi77F2605161828.wav
# Processed in 0.40s: VO1rlouscsi77F2605161828.wav
# Processed in 0.34s: VO2rlouscsi77F2605161829.wav
# Processed in 0.21s: VU1rlouscsi77F2605161830.wav
# Processed in 0.27s: VU2rlouscsi77F2605161830.wav
# Processed in 1.33s: B1lbuairgo52M1606161810.wav
# Processed in 1.11s: B2lbuairgo52M1606161811.wav
# Processed in 0.15s: D1lbuairgo52M1606161812.wav
# Processed in 0.14s: D2lbuairgo52M1606161812.wav
# Processed in 0.80s: FB1lbuairgo52M1606161825.wav
# Processed in 0.84s: PR1lbuairgo52M1606161824.wav
# Processed in 0.53s: VA1lbuairgo52M1606161813.wav
# Processed in 0.15s: VA2lbuairgo52M1606161814.wav
# Processed in 0.63s: VE1lbuairgo52M1606161815.wav
# Processed in 0.13s: VE2lbuairgo52M1606161815.wav
# Processed in 0.56s: VI1lbuairgo52M1606161816.wav
# Processed in 0.12s: VI2lbuairgo52M1606161816.wav
# Processed in 0.62s: VO1lbuairgo52M1606161817.wav
# Processed in 0.13s: VO2lbuairgo52M1606161817.wav
# Processed in 0.55s: VU1lbuairgo52M1606161819.wav
# Processed in 0.14s: VU2lbuairgo52M1606161820.wav
# Processed in 1.72s: B1MBAUROIN45M100220171003.wav
# Processed in 1.37s: B2MBAUROIN45M100220171006.wav
# Processed in 0.08s: D1MBAUROIN45M100220171006.wav
# Processed in 0.07s: D2MBAUROIN45M100220171006.wav
# Processed in 0.60s: FB1MBAUROIN45M100220171015.wav
# Processed in 1.16s: PR1MBAUROIN45M100220171014.wav
# Processed in 1.83s: B1rriovbie49M2605161841.wav
# Processed in 1.15s: B1RROIBVEI49M240120171859.wav
# Processed in 1.30s: B2rriovbie49M2605161842.wav
# Processed in 0.89s: B2RROIBVEI49M240120171902.wav
# Processed in 0.12s: D1rriovbie49M2605161843.wav
# Processed in 0.10s: D1RROIBVEI49M240120171903.wav
# Processed in 0.14s: D2rriovbie49M2605161843.wav
# Processed in 0.08s: D2RROIBVEI49M240120171903.wav
# Processed in 0.71s: FB1rriovbie49M2605161855.wav
# Processed in 0.48s: FB1RROIBVEI49M240120171914.wav
# Processed in 1.12s: PR1rriovbie49M2605161853.wav
# Processed in 0.68s: PR1RROIBVEI49M240120171913.wav
# Processed in 0.35s: VA1rriovbie49M2605161845.wav
# Processed in 0.22s: VA1RROIBVEI49M240120171904.wav
# Processed in 0.18s: VA2rriovbie49M2605161845.wav
# Processed in 0.10s: VA2RROIBVEI49M240120171905.wav
# Processed in 0.27s: VE1rriovbie49M2605161846.wav
# Processed in 0.24s: VE1RROIBVEI49M240120171906.wav
# Processed in 0.28s: VE2rriovbie49M2605161846.wav
# Processed in 0.07s: VE2RROIBVEI49M240120171907.wav
# Processed in 0.29s: VI1rriovbie49M2605161847.wav
# Processed in 0.21s: VI1RROIBVEI49M240120171908.wav
# Processed in 0.23s: VI2rriovbie49M2605161848.wav
# Processed in 0.08s: VI2RROIBVEI49M240120171909.wav
# Processed in 0.27s: VO1rriovbie49M2605161848.wav
# Processed in 0.22s: VO1RROIBVEI49M240120171910.wav
# Processed in 0.32s: VO2rriovbie49M2605161849.wav
# Processed in 0.08s: VO2RROIBVEI49M240120171910.wav
# Processed in 0.22s: VU1rriovbie49M2605161849.wav
# Processed in 0.17s: VU1RROIBVEI49M240120171911.wav
# Processed in 0.30s: VU2rriovbie49M2605161850.wav
# Processed in 0.09s: VU2RROIBVEI49M240120171911.wav
# Processed in 1.92s: B1ssacvhei61M1606161740.wav
# Processed in 1.44s: B2ssacvhei61M1606161741.wav
# Processed in 0.14s: D1ssacvhei61M1606161742.wav
# Processed in 0.14s: D2ssacvhei61M1606161742.wav
# Processed in 0.66s: FB1ssacvhei61M1606161751.wav
# Processed in 1.22s: PR1ssacvhei61M1606161750.wav
# Processed in 0.41s: VA1ssacvhei61M1606161744.wav
# Processed in 0.13s: VA2ssacvhei61M1606161744.wav
# Processed in 0.32s: VE1ssacvhei61M1606161745.wav
# Processed in 0.13s: VE2ssacvhei61M1606161745.wav
# Processed in 0.39s: VI1ssacvhei61M1606161746.wav
# Processed in 0.14s: VI2ssacvhei61M1606161746.wav
# Processed in 0.36s: VO1ssacvhei61M1606161747.wav
# Processed in 0.13s: VO2ssacvhei61M1606161747.wav
# Processed in 0.34s: VU1ssacvhei61M1606161748.wav
# Processed in 0.13s: VU2ssacvhei61M1606161748.wav
# Processed in 1.38s: B1ubguot_t40M1606161755.wav
# Processed in 1.46s: B2ubguot_t40M1606161756.wav
# Processed in 0.14s: D1ubguot_t40M1606161758.wav
# Processed in 0.13s: D2ubguot_t40M1606161758.wav
# Processed in 0.14s: VA2vsiptioz46M1606161705.wav
# Processed in 0.08s: VA2VSIPTIOZ46M240120171925.wav
# Processed in 0.24s: VE1VSIOTLOP47M100220171332.wav
# Processed in 0.27s: VE1vsiptioz46M1606161706.wav
# Processed in 0.19s: VE1VSIPTIOZ46M240120171926.wav
# Processed in 0.10s: VE2VSIOTLOP47M100220171333.wav
# Processed in 0.12s: VE2vsiptioz46M1606161706.wav
# Processed in 0.09s: VE2VSIPTIOZ46M240120171927.wav
# Processed in 0.22s: VI1VSIOTLOP47M100220171334.wav
# Processed in 0.25s: VI1vsiptioz46M1606161707.wav
# Processed in 0.13s: VI1VSIPTIOZ46M240120171928.wav
# Processed in 0.10s: VI2VSIOTLOP47M100220171334.wav
# Processed in 0.13s: VI2vsiptioz46M1606161707.wav
# Processed in 0.08s: VI2VSIPTIOZ46M240120171928.wav
# Processed in 0.21s: VO1VSIOTLOP47M100220171335.wav
# Processed in 0.38s: VO1vsiptioz46M1606161708.wav
# Processed in 0.16s: VO1VSIPTIOZ46M240120171929.wav
# Processed in 0.10s: VO2VSIOTLOP47M100220171335.wav
# Processed in 0.14s: VO2vsiptioz46M1606161708.wav
# Processed in 0.08s: VO2VSIPTIOZ46M240120171930.wav
# Processed in 0.18s: VU1VSIOTLOP47M100220171336.wav
# Processed in 0.34s: VU1vsiptioz46M1606161709.wav
# Processed in 0.14s: VU1VSIPTIOZ46M240120171932.wav
# Processed in 0.10s: VU2VSIOTLOP47M100220171336.wav
# Processed in 0.14s: VU2vsiptioz46M1606161709.wav
# Processed in 0.08s: VU2VSIPTIOZ46M240120171932.wav
#
# ✅ All files processed in 299.71 seconds

# %%
#CHUNKIFICATION OF MDVR DATA

import os
import time
from pydub import AudioSegment

# Define dataset paths
input_root = os.path.join("Dataset", "MDVR Silenced Dataset")
output_root = os.path.join("Dataset", "MDVR Chunked Dataset")
CHUNK_MS = 100
total_chunks = 0

def process_chunks(file_path, output_folder):
    """Splits an audio file into 100ms chunks and stores them in a folder named after the original file."""
    global total_chunks
    start = time.time()
    sound = AudioSegment.from_file(file_path, format="wav")
    file_name = os.path.splitext(os.path.basename(file_path))[0]
    
    # Create a dedicated folder for chunks of this file
    chunk_dir = os.path.join(output_folder, file_name)
    os.makedirs(chunk_dir, exist_ok=True)
    
    # Generate and save chunks
    file_chunks = 0
    for i in range(len(sound) // CHUNK_MS):
        chunk = sound[i * CHUNK_MS:(i + 1) * CHUNK_MS]
        if len(chunk) == CHUNK_MS:  # Ensure full chunk length
            chunk.export(os.path.join(chunk_dir, f"{i+1}.wav"), format="wav")
            file_chunks += 1
    
    total_chunks += file_chunks
    duration = time.time() - start
    print(f"✅ Processed {os.path.basename(file_path)} ({file_chunks} chunks) in {duration:.2f}s")

# Start processing
total_start = time.time()

for group in ["HC", "PD"]:
    input_folder = os.path.join(input_root, group)
    output_folder = os.path.join(output_root, group)
    
    os.makedirs(output_folder, exist_ok=True)
    
    for file in os.listdir(input_folder):
        if file.endswith(".wav"):
            in_path = os.path.join(input_folder, file)
            process_chunks(in_path, output_folder)

# Print summary
total_duration = time.time() - total_start
print(f"\n✅ Total chunks created: {total_chunks}")
print(f"Total processing time: {total_duration:.2f} seconds")
# Out:
# ✅ Processed R_ID00_hc_0_0_0.wav (935 chunks) in 1.02s
# ✅ Processed R_ID01_hc_0_0_0.wav (1357 chunks) in 1.38s
# ✅ Processed R_ID03_hc_0_0_0.wav (978 chunks) in 0.97s
# ✅ Processed R_ID05_hc_0_0_0.wav (857 chunks) in 0.87s
# ✅ Processed R_ID08_hc_0_0_0.wav (744 chunks) in 0.71s
# ✅ Processed R_ID09_hc_0_0_0.wav (809 chunks) in 0.84s
# ✅ Processed R_ID10_hc_0_0_0.wav (1056 chunks) in 1.05s
# ✅ Processed R_ID11_hc_0_0_0.wav (372 chunks) in 0.33s
# ✅ Processed R_ID12_hc_0_0_0.wav (988 chunks) in 0.88s
# ✅ Processed R_ID14_hc_0_0_0.wav (761 chunks) in 0.69s
# ✅ Processed R_ID15_hc_0_0_0.wav (1507 chunks) in 1.43s
# ✅ Processed R_ID19_hc_0_0_0.wav (1106 chunks) in 1.01s
# ✅ Processed R_ID21_hc_0_0_0.wav (552 chunks) in 0.48s
# ✅ Processed R_ID22_hc_0_0_0.wav (1256 chunks) in 1.11s
# ✅ Processed R_ID23_hc_0_0_0.wav (1552 chunks) in 1.39s
# ✅ Processed R_ID25_hc_0_0_0.wav (1393 chunks) in 1.25s
# ✅ Processed R_ID26_hc_0_0_0.wav (1132 chunks) in 1.03s
# ✅ Processed R_ID28_hc_0_0_0.wav (1153 chunks) in 1.01s
# ✅ Processed R_ID31_hc_0_1_1.wav (1618 chunks) in 1.43s
# ✅ Processed R_ID35_hc_0_0_0.wav (636 chunks) in 0.58s
# ✅ Processed R_ID36_hc_0_0_0.wav (1108 chunks) in 1.05s
# ✅ Processed S_ID00_hc_0_0_0.wav (565 chunks) in 0.57s
# ✅ Processed S_ID01_hc_0_0_0.wav (685 chunks) in 0.65s
# ✅ Processed S_ID03_hc_0_0_0.wav (788 chunks) in 0.75s
# ✅ Processed S_ID05_hc_0_0_0.wav (909 chunks) in 0.93s
# ✅ Processed S_ID08_hc_0_0_0.wav (746 chunks) in 0.75s
# ✅ Processed S_ID09_hc_0_0_0.wav (883 chunks) in 1.10s
# ✅ Processed S_ID10_hc_0_0_0.wav (971 chunks) in 1.12s
# ✅ Processed S_ID11_hc_0_0_0.wav (258 chunks) in 0.28s
# ✅ Processed S_ID12_hc_0_0_0.wav (781 chunks) in 0.86s
# ✅ Processed S_ID14_hc_0_0_0.wav (910 chunks) in 1.08s
# ✅ Processed S_ID15_hc_0_0_0.wav (2066 chunks) in 2.59s
# ✅ Processed S_ID19_hc_0_0_0.wav (233 chunks) in 0.28s
# ✅ Processed S_ID21_hc_0_0_0.wav (523 chunks) in 0.62s
# ✅ Processed S_ID22hc_0_0_0.wav (674 chunks) in 0.85s
# ✅ Processed S_ID23_hc_0_0_0.wav (946 chunks) in 1.10s
# ✅ Processed S_ID25_hc_0_0_0.wav (771 chunks) in 0.86s
# ✅ Processed S_ID26_hc_0_0_0.wav (742 chunks) in 0.83s
# ✅ Processed S_ID28_hc_0_0_0.wav (500 chunks) in 0.58s
# ✅ Processed S_ID31_hc_0_1_1.wav (321 chunks) in 0.36s
# ✅ Processed S_ID35_hc_0_0_0.wav (382 chunks) in 0.46s
# ✅ Processed S_ID36_hc_0_0_0.wav (568 chunks) in 0.64s
# ✅ Processed R_ID02_pd_2_0_0.wav (1217 chunks) in 1.33s
# ✅ Processed R_ID04_pd_2_0_1.wav (939 chunks) in 0.87s
# ✅ Processed R_ID06_pd_3_1_1.wav (1393 chunks) in 1.39s
# ✅ Processed R_ID07_pd_2_0_0.wav (975 chunks) in 0.84s
# ✅ Processed R_ID13_pd_3_2_2.wav (615 chunks) in 0.55s
# ✅ Processed R_ID16_pd_2_0_0.wav (1311 chunks) in 1.21s
# ✅ Processed R_ID17_pd_2_1_0.wav (742 chunks) in 0.77s
# ✅ Processed R_ID18_pd_4_3_3.wav (327 chunks) in 0.35s
# ✅ Processed R_ID20_pd_3_0_1.wav (1061 chunks) in 1.16s
# ✅ Processed R_ID24_pd_2_0_0.wav (1158 chunks) in 1.11s
# ✅ Processed R_ID27_pd_4_1_1.wav (648 chunks) in 0.63s
# ✅ Processed R_ID29_pd_3_1_2.wav (1045 chunks) in 0.95s
# ✅ Processed R_ID30_pd_2_1_1.wav (1120 chunks) in 1.19s
# ✅ Processed R_ID32_pd_3_1_1.wav (620 chunks) in 0.58s
# ✅ Processed R_ID33_pd_3_2_2.wav (876 chunks) in 0.87s
# ✅ Processed R_ID34_pd_2_0_0.wav (1008 chunks) in 0.98s
# ✅ Processed S_ID02_pd_2_0_0.wav (1439 chunks) in 1.48s
# ✅ Processed S_ID04_pd_2_0_1.wav (867 chunks) in 0.88s
# ✅ Processed S_ID06_pd_3_1_1.wav (637 chunks) in 0.58s
# ✅ Processed S_ID07_pd_2_0_0.wav (1248 chunks) in 1.11s
# ✅ Processed S_ID13_pd_3_2_2.wav (1611 chunks) in 1.59s
# ✅ Processed S_ID16_pd_2_0_0.wav (958 chunks) in 0.86s
# ✅ Processed S_ID17_pd_2_1_0.wav (475 chunks) in 0.47s
# ✅ Processed S_ID20_pd_3_0_1.wav (410 chunks) in 0.55s
# ✅ Processed S_ID24_pd_2_0_0.wav (728 chunks) in 0.67s
# ✅ Processed S_ID27_pd_4_1_1.wav (1167 chunks) in 1.08s
# ✅ Processed S_ID29_pd_3_1_2.wav (612 chunks) in 0.61s
# ✅ Processed S_ID30_pd_2_1_1.wav (723 chunks) in 0.73s
# ✅ Processed S_ID32_pd_3_1_1.wav (265 chunks) in 0.25s
# ✅ Processed S_ID33_pd_3_2_2.wav (629 chunks) in 0.54s
# ✅ Processed S_ID34_pd_2_0_0.wav (266 chunks) in 0.25s
#
# ✅ Total chunks created: 64182
# Total processing time: 64.26 seconds

# %%
#CHUNKIFICATION OF ITALIAN DATA


import os
import time
from pydub import AudioSegment

input_root = os.path.join("Dataset", "Italian Silenced Dataset")
output_root = os.path.join("Dataset", "Italian Chunked Dataset")
CHUNK_MS = 100
total_chunks = 0

def process_chunks(file_path, output_folder):
    global total_chunks
    start = time.time()
    
    # Load the audio file
    sound = AudioSegment.from_file(file_path, format="wav")
    file_name = os.path.splitext(os.path.basename(file_path))[0]

    
    chunk_dir = os.path.join(output_folder, file_name)
    os.makedirs(chunk_dir, exist_ok=True)
    

    file_chunks = 0
    for i in range(len(sound) // CHUNK_MS):
        chunk = sound[i * CHUNK_MS : (i + 1) * CHUNK_MS]
        
        if len(chunk) == CHUNK_MS:  # Ensure chunk is exactly 100ms
            chunk.export(os.path.join(chunk_dir, f"{file_name}_{i+1}.wav"), format="wav")
            file_chunks += 1
    
    total_chunks += file_chunks
    duration = time.time() - start
    print(f"Processed {os.path.basename(file_path)} ({file_chunks} chunks) in {duration:.2f}s")

total_start = time.time()


for group in ["HC", "PD"]:
    input_folder = os.path.join(input_root, group)
    output_folder = os.path.join(output_root, group)


    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".wav"):

                relative_path = os.path.relpath(root, input_folder)
                in_path = os.path.join(root, file)
                out_path = os.path.join(output_folder, relative_path)

                process_chunks(in_path, out_path)

total_duration = time.time() - total_start
print(f"\n✅ Total chunks created: {total_chunks}")
print(f"Total processing time: {total_duration:.2f} seconds")
# Out:
# Processed B1APGANRET55F170320171104.wav (1010 chunks) in 0.85s
# Processed B2APGANRET55F170320171105.wav (770 chunks) in 0.66s
# Processed D1APGANRET55F170320171106.wav (61 chunks) in 0.06s
# Processed D2APGANRET55F170320171107.wav (70 chunks) in 0.05s
# Processed FB1APGANRET55F170320171115.wav (391 chunks) in 0.41s
# Processed PR1APGANRET55F170320171114.wav (661 chunks) in 0.54s
# Processed VA1APGANRET55F170320171107.wav (130 chunks) in 0.11s
# Processed VA2APGANRET55F170320171108.wav (63 chunks) in 0.05s
# Processed VE1APGANRET55F170320171109.wav (103 chunks) in 0.08s
# Processed VE2APGANRET55F170320171109.wav (56 chunks) in 0.05s
# Processed VI1APGANRET55F170320171109.wav (99 chunks) in 0.08s
# Processed VI2APGANRET55F170320171110.wav (59 chunks) in 0.05s
# Processed VO1APGANRET55F170320171111.wav (95 chunks) in 0.11s
# Processed VO2APGANRET55F170320171111.wav (64 chunks) in 0.06s
# Processed VU1APGANRET55F170320171112.wav (98 chunks) in 0.08s
# Processed VU2APGANRET55F170320171112.wav (64 chunks) in 0.05s
# Processed B1LBULCAAS94M100120171015.wav (375 chunks) in 0.31s
# Processed B2LBULCAAS94M100120171015.wav (382 chunks) in 0.33s
# Processed PR1LBULCAAS94M100120171015..wav (448 chunks) in 0.38s
# Processed B1AMULCAAS94M100120171016.wav (395 chunks) in 0.33s
# Processed B2LBULCAAS94M100120171016.wav (385 chunks) in 0.31s
# Processed PR1LBULCAAS94M100120171016.wav (464 chunks) in 0.39s
# Processed B1LBULCAAS94M100120171017.wav (260 chunks) in 0.21s
# Processed B2LBULCAAS94M100120171017.wav (202 chunks) in 0.18s
# Processed PR1LBULCAAS94M100120171017.wav (380 chunks) in 0.34s
# Processed VO2GGRIAUZL45F020420171823.wav (38 chunks) in 0.04s
# Processed VU1GGRIAUZL45F020420171824.wav (37 chunks) in 0.02s
# Processed VU2GGRIAUZL45F020420171824.wav (34 chunks) in 0.03s
# Processed B1LFEIOONR57F210320171120.wav (593 chunks) in 0.50s
# Processed B2LFEIOONR57F210320171124.wav (548 chunks) in 0.47s
# Processed D1LFEIOONR57F210320171125.wav (60 chunks) in 0.05s
# Processed D2LFEIOONR57F210320171125.wav (59 chunks) in 0.06s
# Processed FB1LFEIOONR57F210320171131.wav (290 chunks) in 0.28s
# Processed PR1LFEIOONR57F210320171130.wav (443 chunks) in 0.37s
# Processed VA1LFEIOONR57F210320171126.wav (38 chunks) in 0.04s
# Processed VA2LFEIOONR57F210320171126.wav (32 chunks) in 0.03s
# Processed VE1LFEIOONR57F210320171126.wav (78 chunks) in 0.08s
# Processed VE2LFEIOONR57F210320171127.wav (57 chunks) in 0.06s
# Processed VI1LFEIOONR57F210320171127.wav (64 chunks) in 0.06s
# Processed VI2LFEIOONR57F210320171127.wav (38 chunks) in 0.03s
# Processed VO1LFEIOONR57F210320171128.wav (44 chunks) in 0.04s
# Processed VO2LFEIOONR57F210320171128.wav (51 chunks) in 0.04s
# Processed VU1LFEIOONR57F210320171128.wav (53 chunks) in 0.04s
# Processed VU2LFEIOONR57F210320171128.wav (63 chunks) in 0.06s
# Processed B1GLIIUSSC57M210320171050.wav (603 chunks) in 0.51s
# Processed B2GLIIUSSC57M210320171051.wav (544 chunks) in 0.47s
# Processed D1GLIIUSSC57M210320171052.wav (64 chunks) in 0.06s
# Processed D2GLIIUSSC57M210320171052.wav (55 chunks) in 0.05s
# Processed FB1GLIIUSSC57M210320171058.wav (240 chunks) in 0.21s
# Processed PR1GLIIUSSC57M210320171057.wav (389 chunks) in 0.33s
# Processed VA1GLIIUSSC57M210320171052.wav (70 chunks) in 0.06s
# Processed VA2GLIIUSSC57M210320171053.wav (59 chunks) in 0.06s
# Processed VE1GLIIUSSC57M210320171053.wav (146 chunks) in 0.12s
# Processed VE2GLIIUSSC57M210320171053.wav (55 chunks) in 0.05s
# Processed VI1GLIIUSSC57M210320171054.wav (123 chunks) in 0.10s
# Processed VI2GLIIUSSC57M210320171054.wav (61 chunks) in 0.05s
# Processed VO1GLIIUSSC57M210320171055.wav (50 chunks) in 0.04s
# Processed VO2GLIIUSSC57M210320171055.wav (55 chunks) in 0.05s
# Processed VU1GLIIUSSC57M210320171055.wav (59 chunks) in 0.05s
# Processed VU2GLIIUSSC57M210320171056.wav (60 chunks) in 0.06s
# Processed B1LBULCAAS94M100120171063.wav (406 chunks) in 0.36s
# Processed B2LBULCAAS94M100120171063.wav (393 chunks) in 0.32s
# Processed PR1LBULCAAS94M100120171063.wav (311 chunks) in 0.30s
# Processed B1LPUUITGI41M230320171109.wav (548 chunks) in 0.46s
# Processed B2LPUUITGI41M230320171110.wav (525 chunks) in 0.43s
# Processed D1LPUUITGI41M230320171110.wav (64 chunks) in 0.05s
# Processed D1LSUUIMGM48F230320171051.wav (65 chunks) in 0.05s
# Processed D2LSUUIMGM48F230320171051.wav (62 chunks) in 0.06s
# Processed FB1LSUUIMGM48F230320171059.wav (260 chunks) in 0.21s
# Processed PR1LSUUIMGM48F230320171058.wav (340 chunks) in 0.28s
# Processed VA1LSUUIMGM48F230320171053.wav (34 chunks) in 0.03s
# Processed VA2LSUUIMGM48F230320171053.wav (35 chunks) in 0.03s
# Processed VE1LSUUIMGM48F230320171054.wav (47 chunks) in 0.03s
# Processed VE2LSUUIMGM48F230320171054.wav (38 chunks) in 0.03s
# Processed VI1LSUUIMGM48F230320171055.wav (47 chunks) in 0.05s
# Processed VI2LSUUIMGM48F230320171055.wav (41 chunks) in 0.03s
# Processed VO1LSUUIMGM48F230320171056.wav (52 chunks) in 0.05s
# Processed VO2LSUUIMGM48F230320171056.wav (43 chunks) in 0.05s
# Processed VU1LSUUIMGM48F230320171057.wav (40 chunks) in 0.03s
# Processed VU2LSUUIMGM48F230320171057.wav (36 chunks) in 0.03s
# Processed B1TMEIRAEC54F230320171150.wav (674 chunks) in 0.59s
# Processed B2TMEIRAEC54F230320171152.wav (586 chunks) in 0.50s
# Processed D1TMEIRAEC54F230320171152.wav (61 chunks) in 0.05s
# Processed D2TMEIRAEC54F230320171152.wav (62 chunks) in 0.05s
# Processed FB1TMEIRAEC54F230320171158.wav (293 chunks) in 0.25s
# Processed PR1TMEIRAEC54F230320171157.wav (541 chunks) in 0.47s
# Processed VA1TMEIRAEC54F230320171153.wav (49 chunks) in 0.04s
# Processed VA2TMEIRAEC54F230320171153.wav (27 chunks) in 0.03s
# Processed VE1TMEIRAEC54F230320171154.wav (49 chunks) in 0.03s
# Processed VE2TMEIRAEC54F230320171154.wav (41 chunks) in 0.05s
# Processed VI1TMEIRAEC54F230320171154.wav (46 chunks) in 0.03s
# Processed VI2TMEIRAEC54F230320171154.wav (40 chunks) in 0.03s
# Processed VO1TMEIRAEC54F230320171155.wav (42 chunks) in 0.05s
# Processed VO2TMEIRAEC54F230320171155.wav (27 chunks) in 0.02s
# Processed VU1TMEIRAEC54F230320171155.wav (39 chunks) in 0.03s
# Processed VU2TMEIRAEC54F230320171155.wav (45 chunks) in 0.04s
# Processed D1VDIET AS47M210320170946.wav (61 chunks) in 0.06s
# Processed D2VDIET AS47M210320170946.wav (63 chunks) in 0.05s
# Processed PR1VDIETAS47M210320170948.wav (631 chunks) in 0.53s
# Processed VA1VDIET AS47M210320170942.wav (17 chunks) in 0.01s
# Processed VA2VDIET AS47M210320170943.wav (53 chunks) in 0.05s
# Processed VE1VDIET AS47M210320170943.wav (100 chunks) in 0.08s
# Processed VE2VDIET AS47M210320170944.wav (49 chunks) in 0.03s
# Processed VI1VDIET AS47M210320170944.wav (83 chunks) in 0.08s
# Processed VI2VDIET AS47M210320170944.wav (60 chunks) in 0.05s
# Processed VO1VDIET AS47M210320170945.wav (133 chunks) in 0.11s
# Processed VO2VDIET AS47M210320170945.wav (63 chunks) in 0.05s
# Processed D2cdaopmoe67M2605161905.wav (50 chunks) in 0.05s
# Processed FB1cdaopmoe67M2605161917.wav (238 chunks) in 0.22s
# Processed PR1cdaopmoe67M2605161916.wav (396 chunks) in 0.49s
# Processed VA1cdaopmoe67M2605161906.wav (172 chunks) in 0.15s
# Processed VA2cdaopmoe67M2605161907.wav (172 chunks) in 0.17s
# Processed VE1cdaopmoe67M2605161909.wav (155 chunks) in 0.16s
# Processed VE2cdaopmoe67M2605161909.wav (162 chunks) in 0.15s
# Processed VI1cdaopmoe67M2605161910.wav (177 chunks) in 0.15s
# Processed VI2cdaopmoe67M2605161911.wav (193 chunks) in 0.20s
# Processed VO1cdaopmoe67M2605161911.wav (185 chunks) in 0.17s
# Processed VO2cdaopmoe67M2605161912.wav (163 chunks) in 0.14s
# Processed VU1cdaopmoe67M2605161913.wav (191 chunks) in 0.17s
# Processed VU2cdaopmoe67M2605161913.wav (200 chunks) in 0.21s
# Processed B1cfaerlei54F2605161738.wav (676 chunks) in 0.65s
# Processed B2cfaerlei54F2605161740.wav (570 chunks) in 0.53s
# Processed D1cfaerlei54F2605161742.wav (50 chunks) in 0.05s
# Processed D2cfaerlei54F2605161742.wav (50 chunks) in 0.04s
# Processed FB1cfaerlei54F2605161816.wav (294 chunks) in 0.28s
# Processed PR1cfaerlei54F2605161815.wav (571 chunks) in 0.53s
# Processed VA1cfaerlei54F2605161745.wav (178 chunks) in 0.18s
# Processed VA2cfaerlei54F2605161745.wav (152 chunks) in 0.14s
# Processed VE1cfaerlei54F2605161747.wav (150 chunks) in 0.14s
# Processed VE2cfaerlei54F2605161748.wav (117 chunks) in 0.11s
# Processed VI1cfaerlei54F2605161751.wav (140 chunks) in 0.13s
# Processed VI2cfaerlei54F2605161752.wav (135 chunks) in 0.13s
# Processed VO1cfaerlei54F2605161755.wav (136 chunks) in 0.13s
# Processed VO2cfaerlei54F2605161756.wav (126 chunks) in 0.11s
# Processed VU1cfaerlei54F2605161808.wav (106 chunks) in 0.11s
# Processed VU2cfaerlei54F2605161810.wav (117 chunks) in 0.10s
# Processed B1GMIAOSVI44M100220170942.wav (682 chunks) in 0.60s
# Processed B2GMIAOSVI44M100220170944.wav (640 chunks) in 0.73s
# Processed D1GMIAOSVI44M100220170945.wav (50 chunks) in 0.05s
# Processed D2GMIAOSVI44M100220170945.wav (54 chunks) in 0.05s
# Processed FB1GMIAOSVI44M100220170952.wav (318 chunks) in 0.25s
# Processed PR1GMIAOSVI44M100220170951.wav (533 chunks) in 0.47s
# Processed VA1GMIAOSVI44M100220170946.wav (77 chunks) in 0.06s
# Processed VA2GMIAOSVI44M100220170946.wav (53 chunks) in 0.05s
# Processed VE1GMIAOSVI44M100220170947.wav (88 chunks) in 0.08s
# Processed VE2GMIAOSVI44M100220170947.wav (58 chunks) in 0.05s
# Processed VI1GMIAOSVI44M100220170948.wav (89 chunks) in 0.08s
# Processed VI2GMIAOSVI44M100220170948.wav (57 chunks) in 0.04s
# Processed VO1GMIAOSVI44M100220170948.wav (95 chunks) in 0.09s
# Processed VA1GPIUUGLL63F100220171023.wav (135 chunks) in 0.14s
# Processed VA2GPIUUGLL63F100220171024.wav (57 chunks) in 0.06s
# Processed VE1GPIUUGLL63F100220171024.wav (269 chunks) in 0.22s
# Processed VE2GPIUUGLL63F100220171025.wav (58 chunks) in 0.03s
# Processed VI1GPIUUGLL63F100220171025.wav (259 chunks) in 0.12s
# Processed VI2GPIUUGLL63F100220171026.wav (58 chunks) in 0.03s
# Processed VO1GPIUUGLL63F100220171026.wav (150 chunks) in 0.05s
# Processed VO2GPIUUGLL63F100220171027.wav (56 chunks) in 0.03s
# Processed VU1GPIUUGLL63F100220171027.wav (171 chunks) in 0.08s
# Processed VU2GPIUUGLL63F100220171027.wav (72 chunks) in 0.03s
# Processed B1GMIAUSST39F100220171156.wav (1496 chunks) in 1.24s
# Processed D1GMIAUSST39F100220171157.wav (54 chunks) in 0.05s
# Processed D2GMIAUSST39F100220171158.wav (56 chunks) in 0.05s
# Processed FB1GMIAUSST39F100220171206.wav (616 chunks) in 0.52s
# Processed PR1GMIAUSST39F100220171204.wav (833 chunks) in 0.71s
# Processed VA1GMIAUSST39F100220171159.wav (76 chunks) in 0.08s
# Processed VE1GMIAUSST39F100220171159.wav (43 chunks) in 0.03s
# Processed VI1GMIAUSST39F100220171200.wav (40 chunks) in 0.05s
# Processed VO1GMIAUSST39F100220171200.wav (46 chunks) in 0.03s
# Processed VU1GMIAUSST39F100220171200.wav (29 chunks) in 0.03s
# Processed B1lloeroun56F2605161922.wav (539 chunks) in 0.51s
# Processed B2lloeroun56F2605161923.wav (509 chunks) in 0.45s
# Processed D1lloeroun56F2605161924.wav (50 chunks) in 0.05s
# Processed D2lloeroun56F2605161924.wav (50 chunks) in 0.05s
# Processed FB1lloeroun56F2605161937.wav (273 chunks) in 0.24s
# Processed PR1lloeroun56F2605161936.wav (491 chunks) in 0.44s
# Processed VA1lloeroun56F2605161926.wav (212 chunks) in 0.20s
# Processed VA2lloeroun56F2605161927.wav (220 chunks) in 0.21s
# Processed VE1lloeroun56F2605161927.wav (201 chunks) in 0.17s
# Processed VE2lloeroun56F2605161928.wav (197 chunks) in 0.19s
# Processed VI1lloeroun56F2605161929.wav (275 chunks) in 0.30s
# Processed VI2lloeroun56F2605161930.wav (351 chunks) in 0.32s
# Processed VO1lloeroun56F2605161931.wav (243 chunks) in 0.22s
# Processed VO2lloeroun56F2605161931.wav (234 chunks) in 0.26s
# Processed VU1lloeroun56F2605161932.wav (274 chunks) in 0.26s
# Processed VU2lloeroun56F2605161933.wav (227 chunks) in 0.23s
# Processed B1rlouscsi77F2605161820.wav (571 chunks) in 0.52s
# Processed B2rlouscsi77F2605161822.wav (522 chunks) in 0.46s
# Processed D1rlouscsi77F2605161822.wav (52 chunks) in 0.05s
# Processed D2rlouscsi77F2605161823.wav (50 chunks) in 0.05s
# Processed FB1rlouscsi77F2605161834.wav (260 chunks) in 0.24s
# Processed PR1rlouscsi77F2605161834.wav (544 chunks) in 0.52s
# Processed VA1rlouscsi77F2605161825.wav (97 chunks) in 0.08s
# Processed VU1VSIOTLOP47M100220171336.wav (129 chunks) in 0.10s
# Processed VU1vsiptioz46M1606161709.wav (155 chunks) in 0.14s
# Processed VU1VSIPTIOZ46M240120171932.wav (114 chunks) in 0.11s
# Processed VU2VSIOTLOP47M100220171336.wav (60 chunks) in 0.06s
# Processed VU2vsiptioz46M1606161709.wav (59 chunks) in 0.07s
# Processed VU2VSIPTIOZ46M240120171932.wav (61 chunks) in 0.05s
#
# ✅ Total chunks created: 170243
# Total processing time: 150.75 seconds

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# def generate_mel_spectrogram(audio_path, save_path):
#     # Load audio (16kHz sample rate)
#     y, sr = librosa.load(audio_path, sr=16000)
    
#     # Ensure audio is exactly 100ms (1600 samples)
#     y = y[:1600] if len(y) > 1600 else np.pad(y, (0, 1600 - len(y)))
    
#     # Generate Mel spectrogram
#     mel_spec = librosa.feature.melspectrogram(
#         y=y,
#     sr=sr,
#     n_fft=256,        # Reduced for more time steps
#     hop_length=128,     # Smaller hop = wider spectrogram
#     n_mels=64,        # Taller spectrogram
#     fmax=4000
#     )
    
#     # Convert to dB and normalize
#     mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())
    
#     # Create a NEW figure and save WITHOUT displaying
#     fig = plt.figure(figsize=(3, 2))  # Explicitly create a figure
#     plt.imshow(norm_spec, cmap='gray', origin='lower', aspect='auto')
#     plt.axis('off')
    
#     # Save FIRST, then close
#     plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
#     plt.close(fig)  # Critical: Close the figure to free memory

# # Example usage
# audio_file = "C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/MDVR Chunked Dataset/ReadText/HC/ID00_hc_0_0_0/ID00_hc_0_0_0_1.wav"
# save_file = "mel_spectrogram.png"
# generate_mel_spectrogram(audio_file, save_file)

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# def generate_mel_spectrogram(audio_path, save_path):
#     # Load audio (100ms @ 16kHz = 1600 samples)
#     y, sr = librosa.load(audio_path, sr=16000)
    
#     # Generate Mel spectrogram
#     mel_spec = librosa.feature.melspectrogram(
#         y=y, sr=sr, 
#         n_fft=512,       # Frequency resolution
#         hop_length=128,   # Time resolution
#         n_mels=64,        # Height (frequency bins)
#         fmax=4000         # Focus on 0–4 kHz
#     )
    
#     # Convert to dB and normalize
#     mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())
    
#     # Save as raw image (no resizing)
#     plt.figure(figsize=(3, 2))
#     plt.axis('off')
#     plt.imshow(norm_spec, cmap='gray', origin='lower', aspect='auto')
#     plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
#     plt.close()

# generate_mel_spectrogram("C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/MDVR Chunked Dataset/ReadText/HC/ID00_hc_0_0_0/ID00_hc_0_0_0_1.wav", "somefile")

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt
# import librosa.display

# def generate_parkinsons_spectrogram(audio_path, save_path):
#     # Load audio with strict 16kHz sampling
#     y, sr = librosa.load(audio_path, mono=True)
    
#     # Generate Mel spectrogram with validation
#     mel_spec = librosa.feature.melspectrogram(
#         y=y,
#         sr=16000,
#         n_fft = 512,
#         hop_length = 128,
#         n_mels = 64,
#         fmax = 4000,
#         power=1.0  # Use power=1 for energy spectrogram
#     )

#     # Convert to dB scale and normalize
    
#     # mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
#     mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

#     # # Create figure with proper dimensions
#     # fig = plt.figure(figsize=(3, 2), dpi=300)
#     # ax = fig.add_subplot(111)
    
#     # # Display spectrogram
#     # img = librosa.display.specshow(
#     #     norm_spec,
#     #     x_axis='time',
#     #     y_axis='mel',
#     #     sr=16000,
#     #     fmax=4000,
#     #     hop_length=128,
#     #     cmap='gray',
#     #     ax=ax
#     # )
    
#     # # Remove axes and save
#     # ax.axis('off')
#     # plt.tight_layout(pad=0)
#     # plt.savefig(
#     #     save_path,
#     #     bbox_inches='tight',
#     #     pad_inches=0,
#     #     dpi=100,
#     #     format='png'
#     # )
#     # plt.close(fig)

#     # Create figure with ML-optimized dimensions
#     target_height = 64    # Matches n_mels
#     target_width = 21     # (1600 - 256)//64 + 1 = 21 time steps
#     dpi = 100
    
#     fig = plt.figure(figsize=(target_width/dpi, target_height/dpi), dpi=dpi)
#     ax = fig.add_subplot(111)
    
#     # Display spectrogram
#     librosa.display.specshow(
#         norm_spec,
#         x_axis='time',
#         y_axis='mel',
#         sr=16000,
#         fmax=4000,
#         hop_length=64,
#         cmap='gray',
#         ax=ax
#     )
    
#     ax.axis('off')
#     plt.savefig(
#         save_path,
#         bbox_inches='tight',
#         pad_inches=0,
#         dpi=dpi
#     )
#     plt.close(fig)

#     # Quality check
#     print(f"Generated spectrogram dimensions: {norm_spec.shape}")
#     print(f"Min value: {norm_spec.min():.4f}, Max value: {norm_spec.max():.4f}")

# # Example usage
# audio_file = "C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/MDVR Chunked Dataset/ReadText/HC/ID00_hc_0_0_0/ID00_hc_0_0_0_1.wav"
# output_file = "parkinsons_spectrogram3.png"

# generate_parkinsons_spectrogram(audio_file, output_file)
# Out:
# Generated spectrogram dimensions: (64, 18)
# Min value: 0.0000, Max value: 1.0000

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt
# from PIL import Image

# def generate_parkinsons_spectrogram(audio_path, output_path, target_size=(64, 64)):
#     """
#     Processes 100ms audio chunk to create ML-ready spectrogram image.
    
#     Parameters:
#         audio_path (str): Path to input audio file (.wav)
#         output_path (str): Path to save resized spectrogram image (.png)
#         target_size (tuple): Final image dimensions (height, width)
#     """
#     # 1. Load and Preprocess Audio
#     y, sr = librosa.load(audio_path, sr=16000, mono=True)
#     y = y[:1600] if len(y) >= 1600 else np.pad(y, (0, max(0, 1600 - len(y))))
    
#     # 2. Generate Mel Spectrogram (Parkinson's-optimized)
#     n_fft = 512
#     hop_length = 64
#     n_mels = 64
#     fmax = 4000

#     mel_spec = librosa.feature.melspectrogram(
#         y=y,
#         sr=sr,
#         n_fft=n_fft,
#         hop_length=hop_length,
#         n_mels=n_mels,
#         fmax=fmax,
#         power=1.0
#     )
    
#     # 3. Convert to dB and Normalize
#     mel_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_db - mel_db.min()) / (mel_db.max() - mel_db.min())

#     # 4. Save Native Spectrogram (Temporary)
#     temp_path = "temp_native.png"
#     plt.figure(figsize=(3, 2))
#     plt.imshow(norm_spec, cmap='gray', aspect='auto', origin='lower')
#     plt.axis('off')
#     plt.savefig(temp_path, bbox_inches='tight', pad_inches=0)
#     plt.close()

#     # 5. Resize for ML Compatibility
#     img = Image.open(temp_path).convert('L')  # Convert to grayscale
#     resized_img = img.resize(target_size, Image.LANCZOS)
#     resized_img.save(output_path)

#     # 6. Cleanup and Validation
#     print(f"Native dimensions: {norm_spec.shape} → Resized: {target_size}")
#     print(f"Pixel range: [{resized_img.getextrema()[0]}, {resized_img.getextrema()[1]}]")

# # Usage Example
# generate_parkinsons_spectrogram(
#     audio_path="C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/MDVR Chunked Dataset/ReadText/HC/ID00_hc_0_0_0/ID00_hc_0_0_0_1.wav",
#     output_path="parkinsons_spec.png",
#     target_size=(64, 64)  # (height, width) for CNN compatibility
# )
# Out:
# Native dimensions: (64, 26) → Resized: (64, 64)
# Pixel range: [0, 254]

# %%
# import librosa
# import numpy as np
# import matplotlib.pyplot as plt

# def generate_parkinsons_spectrogram(audio_path, save_path):
#     # Load audio with strict 16kHz sampling
#     y, sr = librosa.load(audio_path, sr=16000, mono=True)

#     # Generate Mel spectrogram
#     mel_spec = librosa.feature.melspectrogram(
#         y=y,
#         sr=sr,
#         n_fft=512,
#         hop_length=64,
#         n_mels=64,
#         fmax=4000,
#         power=1.0
#     )

#     # Convert to dB scale and normalize
#     mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

#     # Create figure with optimal dimensions (64:32 aspect ratio)
#     fig = plt.figure(figsize=(3.2, 1.3), dpi=300)
#     ax = fig.add_subplot(111)

#     # Display spectrogram (for saving only)
#     plt.imshow(norm_spec, aspect='auto', cmap='gray', origin='lower')

#     # Remove axes and save
#     ax.axis('off')
#     plt.savefig(save_path, bbox_inches='tight', pad_inches=0, format='png')
#     plt.close(fig)

# # Example usage
# audio_file = "C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/MDVR Chunked Dataset/ReadText/HC/ID00_hc_0_0_0/ID00_hc_0_0_0_1.wav"
# output_file = "parkinsons_spectrogram2.1.png"

# generate_parkinsons_spectrogram(audio_file, output_file)

# %%
#MDVR SPECTRAL DATASET


import os
import time
import librosa
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from PIL import Image

# Configure paths
# input_root = "Dataset/MDVR Chunked Dataset"
# output_root = "Dataset/MDVR Spectrogram Dataset"

input_root = r"/home/nigmu/NPersonal/Projects/SDP/nigmu-parkinsons_disease_prediction/Dataset/MDVR Chunked Dataset"
output_root = r"/home/nigmu/NPersonal/Projects/SDP/nigmu-parkinsons_disease_prediction/Dataset/MDVR"

os.makedirs(output_root, exist_ok=True)

def generate_parkinsons_spectrogram(audio_path, save_path):
    """Generate and save spectrogram images."""
    y, sr = librosa.load(audio_path, sr=16000, mono=True)

    mel_spec = librosa.feature.melspectrogram(
        y=y, sr=sr, n_fft=512, hop_length=64, n_mels=64, fmax=4000, power=1.0
    )

    mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
    norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

    fig = plt.figure(figsize=(3.2, 1.3), dpi=200)

    ax = fig.add_subplot(111)
    plt.imshow(norm_spec, aspect='auto', cmap='gray', origin='lower')
    ax.axis('off')

    plt.savefig(save_path, bbox_inches='tight', pad_inches=0, format='png')

    
    
    def force_grayscale(image_path):
        img = Image.open(image_path).convert("L")  # Convert to grayscale (1 channel)
        img.save(image_path)  # Overwrite with grayscale version

    force_grayscale(save_path)

    
    
    plt.close(fig)

# Start time tracking
start_time = time.time()
processed_files = 0
total_files = sum(len(files) for _, _, files in os.walk(input_root) if any(f.endswith('.wav') for f in files))

print(f"🔄 Processing {total_files} files...")

for category in ["HC", "PD"]:
    category_input_folder = os.path.join(input_root, category)
    category_output_folder = os.path.join(output_root, category)

    if not os.path.exists(category_input_folder):
        continue  # Skip if category doesn't exist

    os.makedirs(category_output_folder, exist_ok=True)

    for chunk_folder in os.listdir(category_input_folder):
        chunk_input_path = os.path.join(category_input_folder, chunk_folder)
        chunk_output_path = os.path.join(category_output_folder, chunk_folder)

        if not os.path.isdir(chunk_input_path):
            continue  # Skip non-folder files

        os.makedirs(chunk_output_path, exist_ok=True)

        for file in os.listdir(chunk_input_path):
            if file.endswith(".wav"):
                in_path = os.path.join(chunk_input_path, file)
                out_path = os.path.join(chunk_output_path, f"{os.path.splitext(file)[0]}.png")

                generate_parkinsons_spectrogram(in_path, out_path)

                processed_files += 1
                elapsed_time = time.time() - start_time
                time_per_image = elapsed_time / processed_files
                remaining_files = total_files - processed_files
                estimated_remaining_time = remaining_files * time_per_image

                print(
                    f"✅ Processed {processed_files}/{total_files} files | "
                    f"Time per image: {time_per_image:.2f}s | "
                    f"Remaining: {remaining_files} files (~{estimated_remaining_time:.2f}s left)", end='\r'
                )

# Final statistics
total_time = time.time() - start_time
print(f"\n✅ Success! Created {processed_files} spectrogram images in {total_time:.2f}s")
# Out:
# 🔄 Processing 64182 files...
# ✅ Processed 64182/64182 files | Time per image: 0.02s | Remaining: 0 files (~0.00s left))))))))
# ✅ Success! Created 64182 spectrogram images in 1283.24s

# %%
# #ITALIAN GRAPH DATA GENERATION


# import os
# import time
# import gc
# import librosa
# import numpy as np
# import matplotlib
# matplotlib.use('Agg')
# import matplotlib.pyplot as plt

# # Configure paths
# input_root = r"C:\NPersonal\Projects\SDP\Prediction Stuff\Dataset\Italian Chunked Dataset"
# output_root = r"C:\NPersonal\Projects\SDP\Prediction Stuff\Dataset\Italian Spectrogram Dataset"
# os.makedirs(output_root, exist_ok=True)

# def generate_parkinsons_spectrogram(audio_path, save_path):
#     """Generate and save spectrogram images."""
#     y, sr = librosa.load(audio_path, sr=16000, mono=True)

#     mel_spec = librosa.feature.melspectrogram(
#         y=y, sr=sr, n_fft=512, hop_length=64, n_mels=64, fmax=4000, power=1.0
#     )

#     mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
#     norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

#     fig = plt.figure(figsize=(3.2, 1.3), dpi=200)
#     ax = fig.add_subplot(111)

#     plt.imshow(norm_spec, aspect='auto', cmap='gray', origin='lower')
#     ax.axis('off')

#     plt.savefig(save_path, bbox_inches='tight', pad_inches=0, format='png')
#     plt.close(fig)

# # Start time tracking
# start_time = time.time()

# # Get total number of files first
# total_files = sum(
#     len(files) for group in ["HC", "PD"] 
#     for _, _, files in os.walk(os.path.join(input_root, group)) if any(f.endswith('.wav') for f in files)
# )
# processed_files = 0

# print(f"🔄 Processing {total_files} files...")

# # Process both HC and PD folders
# for group in ["HC", "PD"]:
#     input_folder = os.path.join(input_root, group)
#     output_folder = os.path.join(output_root, group)

#     for root, _, files in os.walk(input_folder):
#         for file in files:
#             if file.lower().endswith(".wav"):
#                 file_start_time = time.time()

#                 # Get relative path to maintain folder structure
#                 relative_path = os.path.relpath(root, input_folder)
#                 out_dir = os.path.join(output_folder, relative_path)
#                 os.makedirs(out_dir, exist_ok=True)

#                 # Define input and output paths
#                 in_path = os.path.join(root, file)
#                 out_path = os.path.join(out_dir, f"{os.path.splitext(file)[0]}.png")

#                 generate_parkinsons_spectrogram(in_path, out_path)

#                 processed_files += 1
#                 elapsed_time = time.time() - start_time
#                 time_per_image = elapsed_time / processed_files
#                 remaining_files = total_files - processed_files
#                 estimated_remaining_time = remaining_files * time_per_image

#                 print(
#                     f"✅ Processed {processed_files}/{total_files} files | "
#                     f"Time per image: {time_per_image:.2f}s | "
#                     f"Remaining: {remaining_files} files (~{estimated_remaining_time:.2f}s left)", end='\r'
#                 )

# # Final statistics
# total_time = time.time() - start_time
# print(f"\n✅ Success! Created {processed_files} spectrogram images in {total_time:.2f}s")

# %%
#ITALIAN SPECTROGRAM DATA GENERATION


import os
import time
import gc
import librosa
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from PIL import Image

# Configure paths
# input_root = "Dataset/Italian Chunked Dataset"
# output_root = "Dataset/Italian Spectrogram Dataset"

input_root = r"/home/nigmu/NPersonal/Projects/SDP/nigmu-parkinsons_disease_prediction/Dataset/Italian Chunked Dataset"
output_root = r"/home/nigmu/NPersonal/Projects/SDP/nigmu-parkinsons_disease_prediction/Dataset/Italian Dataset"
checkpoint_file = "processed_files.txt"

# Load previously processed files
processed_files_set = set()
if os.path.exists(checkpoint_file):
    with open(checkpoint_file, "r") as f:
        processed_files_set = set(line.strip() for line in f)

def save_checkpoint(file_path):
    """Append a processed file to the checkpoint file."""
    with open(checkpoint_file, "a") as f:
        f.write(file_path + "\n")

def generate_parkinsons_spectrogram(audio_path, save_path):
    """Generate and save spectrogram images."""
    y, sr = librosa.load(audio_path, sr=16000, mono=True)

    mel_spec = librosa.feature.melspectrogram(
        y=y, sr=sr, n_fft=512, hop_length=64, n_mels=64, fmax=4000, power=1.0
    )

    mel_spec_db = librosa.amplitude_to_db(mel_spec, ref=np.max)
    norm_spec = (mel_spec_db - mel_spec_db.min()) / (mel_spec_db.max() - mel_spec_db.min())

    fig = plt.figure(figsize=(3.2, 1.3), dpi=200)
    ax = fig.add_subplot(111)

    plt.imshow(norm_spec, aspect='auto', cmap='gray', origin='lower')
    ax.axis('off')

    plt.savefig(save_path, bbox_inches='tight', pad_inches=0, format='png')



    def force_grayscale(image_path):
        img = Image.open(image_path).convert("L")  # Convert to grayscale (1 channel)
        img.save(image_path)  # Overwrite with grayscale version

    force_grayscale(save_path)

    

    plt.close(fig)

# Start time tracking
start_time = time.time()

# Get total number of files first
total_files = sum(
    len(files) for group in ["HC", "PD"] 
    for _, _, files in os.walk(os.path.join(input_root, group)) if any(f.endswith('.wav') for f in files)
)
processed_files = len(processed_files_set)

print(f"🔄 Processing {total_files} files... (Resuming from last checkpoint)")

# Process both HC and PD folders
for group in ["HC", "PD"]:
    input_folder = os.path.join(input_root, group)
    output_folder = os.path.join(output_root, group)

    for root, _, files in os.walk(input_folder):
        for file in files:
            if file.lower().endswith(".wav"):
                in_path = os.path.join(root, file)
                out_dir = os.path.join(output_folder, os.path.relpath(root, input_folder))
                os.makedirs(out_dir, exist_ok=True)
                out_path = os.path.join(out_dir, f"{os.path.splitext(file)[0]}.png")

                # Skip if already processed
                if in_path in processed_files_set:
                    continue

                file_start_time = time.time()

                generate_parkinsons_spectrogram(in_path, out_path)

                # Save progress
                save_checkpoint(in_path)
                processed_files += 1

                elapsed_time = time.time() - start_time
                time_per_image = elapsed_time / processed_files
                remaining_files = total_files - processed_files
                estimated_remaining_time = remaining_files * time_per_image

                print(
                    f"✅ Processed {processed_files}/{total_files} files | "
                    f"Time per image: {time_per_image:.2f}s | "
                    f"Remaining: {remaining_files} files (~{estimated_remaining_time:.2f}s left)", end='\r'
                )

# Final statistics
total_time = time.time() - start_time
print(f"\n✅ Success! Created {processed_files} spectrogram images in {total_time:.2f}s")
# Out:
# 🔄 Processing 170243 files... (Resuming from last checkpoint)
#
# ✅ Success! Created 170243 spectrogram images in 2.92s

# %%
#SILENCE REMOVAL TESTING



from pydub import AudioSegment
from pydub.silence import split_on_silence

def process_audio(input_file, output_file):
    sound = AudioSegment.from_file(input_file, format="wav")
    audio_chunks = split_on_silence(sound, min_silence_len=100, silence_thresh=-45, keep_silence=500)
    
    combined = sum(audio_chunks, AudioSegment.empty())
    combined.export(output_file, format="wav")
    print(f"✅ Processed: {output_file}")

# Example usage
process_audio("C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/Italian Dataset/PD/Anna B/B1ABNINSAC46F240120171753.wav", "silenced output.wav")
# Out:
# ✅ Processed: silenced output.wav

# %%
#SILENCE REMOVAL TESTING



from pydub import AudioSegment
from pydub.silence import split_on_silence

def process_audio(input_file, output_file):
    sound = AudioSegment.from_file(input_file, format="wav")
    audio_chunks = split_on_silence(sound, min_silence_len=100, silence_thresh=-40, keep_silence=500)
    
    combined = sum(audio_chunks, AudioSegment.empty())
    combined.export(output_file, format="wav")
    print(f"✅ Processed: {output_file}")

# Example usage
process_audio("C:/NPersonal/Projects/SDP/Prediction Stuff/Dataset/MDVR Trimmed Downsampled Dataset/ReadText/HC/ID00_hc_0_0_0.wav", "trimmed silenced output.wav")
# Out:
# ✅ Processed: trimmed silenced output.wav
